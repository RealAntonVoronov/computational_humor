# %% [markdown]
# <a href="https://colab.research.google.com/github/RealAntonVoronov/computational_humour/blob/master/from_pretrained.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Машинный перевод с помощью openNMT для соревнования STAPLE от Duolingo

# %% [markdown]
# ## Загрузка данных.
#
# Так как данных предоставленных орагнизаторами явно недостаточно для того чтобы обучить полноценную языковую модель, для каждого из 5 языков были загружены параллельные корпуса субтитров. (http://opus.nlpl.eu/OpenSubtitles-v2016.php) Данные можно также найти на сервере nlp1 в папке `voronov/data/OpenSubtitles`.

# %%
# this is for colab skip if you don't need to connect to drive)
import os
from google.colab import drive
drive.mount('/content/gdrive')

course = 'en_pt'
path_to_corpora = os.path.join('/content/gdrive/My Drive/data/work/Panchenko/corpora/OpenSubtitles/', course)
path_to_duolingo = os.path.join('/content/gdrive/My Drive/data/work/Panchenko/duolingo/data/', course)
path_to_model = os.path.join('/content/gdrive/My Drive/data/work/Panchenko/language_models', course)
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
os.chdir(path_to_corpora)

# %%
# !wget http://opus.nlpl.eu/download.php?f=OpenSubtitles/v2016/moses/en-ko.txt.zip
# !unzip  'download.php?f=OpenSubtitles%2Fv2016%2Fmoses%2Fen-ko.txt.zip'
# Out:
# --2020-03-25 14:12:00--  http://opus.nlpl.eu/download.php?f=OpenSubtitles/v2016/moses/en-ko.txt.zip
# Resolving opus.nlpl.eu (opus.nlpl.eu)... 193.166.25.9
# Connecting to opus.nlpl.eu (opus.nlpl.eu)|193.166.25.9|:80... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://object.pouta.csc.fi/OPUS-OpenSubtitles/v2016/moses/en-ko.txt.zip [following]
# --2020-03-25 14:12:00--  https://object.pouta.csc.fi/OPUS-OpenSubtitles/v2016/moses/en-ko.txt.zip
# Resolving object.pouta.csc.fi (object.pouta.csc.fi)... 86.50.254.18, 86.50.254.19
# Connecting to object.pouta.csc.fi (object.pouta.csc.fi)|86.50.254.18|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 12433629 (12M) [application/zip]
# Saving to: ‘download.php?f=OpenSubtitles%2Fv2016%2Fmoses%2Fen-ko.txt.zip’
#
# download.php?f=Open 100%[===================>]  11.86M  26.1MB/s    in 0.5s
#
# 2020-03-25 14:12:01 (26.1 MB/s) - ‘download.php?f=OpenSubtitles%2Fv2016%2Fmoses%2Fen-ko.txt.zip’ saved [12433629/12433629]
#
# Archive:  download.php?f=OpenSubtitles%2Fv2016%2Fmoses%2Fen-ko.txt.zip
#   inflating: OpenSubtitles.en-ko.en
#   inflating: OpenSubtitles.en-ko.ko
#   inflating: OpenSubtitles.en-ko.ids

# %% [markdown]
# Для правильного запуска openNMT понадобится разбить данные на трейн часть и на валидационную. Я решил использовать всего 1 миллион пар предложений (для корейского языка всего было доступно только 370 тысяч предложений) для обучения и 5000 пар для валидации (это не в прямом смысле валидация, она нужна только для корректной работы скриптов openNMT, в их руководстве сказано, что 5000 будет достаточно)

# %%
# !wc -l OpenSubtitles.en-ko.en
# Out:
# 370702 OpenSubtitles.en-ko.en

# %%
# !head -n 365000 'OpenSubtitles.en-ko.en' > 'train_subtitles_1m_en.txt'
# !head -n 365000 'OpenSubtitles.en-ko.ko' > 'train_subtitles_1m_ko.txt'
# !tail -n 5000 'OpenSubtitles.en-ko.en' > 'dev_subtitles_en.txt'
# !tail -n 5000 'OpenSubtitles.en-ko.ko' > 'dev_subtitles_ko.txt'

# %% [markdown]
# ## Данные Duolingo
#
# Для составления предсказания для соревнования Duolingo я взял файл формата `*.aws_baseline.pred.txt`, который содержит по одному референсному переводу от Amazon для каждого предложения, предобработал его (убрал префиксы у строчек, соединил строчки "сообщение-перевод" в одну, разделённую табом, удалил пустые строчки) и разбил на два файла: с исходным языком и таргетным. Для того чтобы на стадии предсказания точно не возникло незнакомых для модели слов, я добавил полученные файлы в обучающую выборку.

# %%
os.chdir(os.path.join(path_to_duolingo, 'train'))
#remove all markers | remove blank lines | combine every two lines in one
#!sed 's/.*|//g' train.en_hu.aws_baseline.pred.txt | grep . | paste -d "\t"  - - > train_duolingo_en_hu.txt

# %%
with open('train_duolingo_en_ko.txt') as f, open('train_duolingo_en.txt', 'w') as file_en, \
open('train_duolingo_ko.txt', 'w') as file_ko:
    for line in f.readlines():
        pair = line.strip().split('\t')
        file_en.writelines(pair[0]+'\n')
        file_ko.writelines(pair[1]+'\n')

# %%
# !tail -5 ../../../../corpora/OpenSubtitles/en_ko/train_subtitles_1m_en.txt
# !cat train_duolingo_en.txt >> ../../../../corpora/OpenSubtitles/en_ko/train_subtitles_1m_en.txt
# !cat train_duolingo_ko.txt >> ../../../../corpora/OpenSubtitles/en_ko/train_subtitles_1m_ko.txt
# !tail -5 ../../../../corpora/OpenSubtitles/en_ko/train_subtitles_1m_en.txt
# Out:
# Again, nothing witchy.
# Ghost?
# Hard to say.
# I mean, there's EMF in the church, but it's built on a burial ground.
# You know that all the victims recently went to confession?
# english is an international language.
# which floor is it?
# the waiter has asked everybody.
# it is a beautiful bird.
# i count.

# %% [markdown]
# ## Обучение

# %%
# !pip install OpenNMT-py
# Out:
# Requirement already satisfied: OpenNMT-py in /usr/local/lib/python3.6/dist-packages (1.1.1)
# Requirement already satisfied: torch>=1.4.0 in /usr/local/lib/python3.6/dist-packages (from OpenNMT-py) (1.4.0)
# Requirement already satisfied: tqdm~=4.30.0 in /usr/local/lib/python3.6/dist-packages (from OpenNMT-py) (4.30.0)
# Requirement already satisfied: flask in /usr/local/lib/python3.6/dist-packages (from OpenNMT-py) (1.1.1)
# Requirement already satisfied: configargparse in /usr/local/lib/python3.6/dist-packages (from OpenNMT-py) (1.1)
# Requirement already satisfied: torchtext==0.4.0 in /usr/local/lib/python3.6/dist-packages (from OpenNMT-py) (0.4.0)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from OpenNMT-py) (1.12.0)
# Requirement already satisfied: tensorboard>=1.14 in /usr/local/lib/python3.6/dist-packages (from OpenNMT-py) (2.1.1)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.6/dist-packages (from OpenNMT-py) (3.13)
# Requirement already satisfied: waitress in /usr/local/lib/python3.6/dist-packages (from OpenNMT-py) (1.4.3)
# Requirement already satisfied: pyonmttok==1.*; platform_system == "Linux" in /usr/local/lib/python3.6/dist-packages (from OpenNMT-py) (1.18.3)
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from OpenNMT-py) (0.16.0)
# Requirement already satisfied: Werkzeug>=0.15 in /usr/local/lib/python3.6/dist-packages (from flask->OpenNMT-py) (1.0.0)
# Requirement already satisfied: itsdangerous>=0.24 in /usr/local/lib/python3.6/dist-packages (from flask->OpenNMT-py) (1.1.0)
# Requirement already satisfied: Jinja2>=2.10.1 in /usr/local/lib/python3.6/dist-packages (from flask->OpenNMT-py) (2.11.1)
# Requirement already satisfied: click>=5.1 in /usr/local/lib/python3.6/dist-packages (from flask->OpenNMT-py) (7.1.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from torchtext==0.4.0->OpenNMT-py) (1.18.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from torchtext==0.4.0->OpenNMT-py) (2.21.0)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.6/dist-packages (from tensorboard>=1.14->OpenNMT-py) (0.9.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.6/dist-packages (from tensorboard>=1.14->OpenNMT-py) (3.2.1)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.6/dist-packages (from tensorboard>=1.14->OpenNMT-py) (46.0.0)
# Requirement already satisfied: protobuf>=3.6.0 in /usr/local/lib/python3.6/dist-packages (from tensorboard>=1.14->OpenNMT-py) (3.10.0)
# Requirement already satisfied: wheel>=0.26; python_version >= "3" in /usr/local/lib/python3.6/dist-packages (from tensorboard>=1.14->OpenNMT-py) (0.34.2)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.6/dist-packages (from tensorboard>=1.14->OpenNMT-py) (0.4.1)
# Requirement already satisfied: grpcio>=1.24.3 in /usr/local/lib/python3.6/dist-packages (from tensorboard>=1.14->OpenNMT-py) (1.27.2)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /usr/local/lib/python3.6/dist-packages (from tensorboard>=1.14->OpenNMT-py) (1.7.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.6/dist-packages (from Jinja2>=2.10.1->flask->OpenNMT-py) (1.1.1)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->torchtext==0.4.0->OpenNMT-py) (3.0.4)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->torchtext==0.4.0->OpenNMT-py) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->torchtext==0.4.0->OpenNMT-py) (2019.11.28)
# Requirement already satisfied: idna<2.9,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->torchtext==0.4.0->OpenNMT-py) (2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=1.14->OpenNMT-py) (1.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tensorboard>=1.14->OpenNMT-py) (0.2.8)
# Requirement already satisfied: cachetools<3.2,>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tensorboard>=1.14->OpenNMT-py) (3.1.1)
# Requirement already satisfied: rsa<4.1,>=3.1.4 in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tensorboard>=1.14->OpenNMT-py) (4.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=1.14->OpenNMT-py) (3.1.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.6/dist-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard>=1.14->OpenNMT-py) (0.4.8)

# %%
os.chdir(os.path.join(path_to_model, 'openNMT'))

# %%
# !onmt_preprocess -train_src ../../../corpora/OpenSubtitles/en_vi/train_subtitles_1m_en.txt \
-train_tgt ../../../corpora/OpenSubtitles/en_vi/train_subtitles_1m_vi.txt \
-valid_src ../../../corpora/OpenSubtitles/en_vi/dev_subtitles_en.txt \
-valid_tgt ../../../corpora/OpenSubtitles/en_vi/dev_subtitles_vi.txt \
-tgt_vocab_size 50000 -src_vocab_size 50000 --src_seq_length 25 --tgt_seq_length 25 \
-save_data nmt_subs_en_vi
# Out:
# [2020-03-26 12:23:25,754 INFO] Extracting features...
# [2020-03-26 12:23:26,631 INFO]  * number of source features: 0.
# [2020-03-26 12:23:26,632 INFO]  * number of target features: 0.
# [2020-03-26 12:23:26,632 INFO] Building `Fields` object...
# [2020-03-26 12:23:26,633 INFO] Building & saving training data...
# [2020-03-26 12:23:29,506 INFO] Building shard 0.
# [2020-03-26 12:24:09,090 INFO]  * saving 0th train data shard to nmt_subs_en_vi.train.0.pt.
# [2020-03-26 12:24:32,843 INFO] Building shard 1.
# [2020-03-26 12:24:32,987 INFO]  * saving 1th train data shard to nmt_subs_en_vi.train.1.pt.
# [2020-03-26 12:24:33,406 INFO]  * tgt vocab size: 50004.
# [2020-03-26 12:24:33,731 INFO]  * src vocab size: 50002.
# [2020-03-26 12:24:34,575 INFO] Building & saving validation data...
# [2020-03-26 12:24:35,621 INFO] Building shard 0.
# [2020-03-26 12:24:35,778 INFO]  * saving 0th valid data shard to nmt_subs_en_vi.valid.0.pt.

# %% [markdown]
# Это облегченная модель трансформера (чтобы обучение занимало адекватное время (~12 часов). Я уменьшил `rnn_size`, `word_vec_size`, `heads`, `training_steps` в 2 раза. Остальное оставил таким же как указано в рекомендациях openNMT, которые якобы повторяют исходный сетап Google.

# %%
# !onmt_train -data nmt_subs_en_vi -save_model transformer \
        -layers 6 -rnn_size 256 -word_vec_size 256 -transformer_ff 2048 -heads 4  \
        -encoder_type transformer -decoder_type transformer -position_encoding \
        -train_steps 100000  -max_generator_batches 2 -dropout 0.1 \
        -batch_size 4096 -batch_type tokens -normalization tokens  -accum_count 2 \
        -optim adam -adam_beta2 0.998 -decay_method noam -warmup_steps 8000 -learning_rate 2 \
        -max_grad_norm 0 -param_init 0  -param_init_glorot \
        -label_smoothing 0.1 -valid_steps 10000 -save_checkpoint_steps 5000 \
        -world_size 1 -gpu_ranks 0
# i omitted output with training statistics for better representation
# Out:
# [2020-03-26 12:25:40,102 INFO]  * src vocab size = 50002
# [2020-03-26 12:25:40,102 INFO]  * tgt vocab size = 50004
# [2020-03-26 12:25:40,103 INFO] Building model...
# [2020-03-26 12:25:49,045 INFO] NMTModel(
#   (encoder): TransformerEncoder(
#     (embeddings): Embeddings(
#       (make_embedding): Sequential(
#         (emb_luts): Elementwise(
#           (0): Embedding(50002, 256, padding_idx=1)
#         )
#         (pe): PositionalEncoding(
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#     )
#     (transformer): ModuleList(
#       (0): TransformerEncoderLayer(
#         (self_attn): MultiHeadedAttention(
#           (linear_keys): Linear(in_features=256, out_features=256, bias=True)
#           (linear_values): Linear(in_features=256, out_features=256, bias=True)
#           (linear_query): Linear(in_features=256, out_features=256, bias=True)
#           (softmax): Softmax(dim=-1)
#           (dropout): Dropout(p=0.1, inplace=False)
#           (final_linear): Linear(in_features=256, out_features=256, bias=True)
#         )
#         (feed_forward): PositionwiseFeedForward(
#           (w_1): Linear(in_features=256, out_features=2048, bias=True)
#           (w_2): Linear(in_features=2048, out_features=256, bias=True)
#           (layer_norm): LayerNorm((256,), eps=1e-06, elementwise_affine=True)
#           (dropout_1): Dropout(p=0.1, inplace=False)
#           (relu): ReLU()
#           (dropout_2): Dropout(p=0.1, inplace=False)
#         )
#         (layer_norm): LayerNorm((256,), eps=1e-06, elementwise_affine=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#       (1): TransformerEncoderLayer(
#         (self_attn): MultiHeadedAttention(
#           (linear_keys): Linear(in_features=256, out_features=256, bias=True)
#           (linear_values): Linear(in_features=256, out_features=256, bias=True)
#           (linear_query): Linear(in_features=256, out_features=256, bias=True)
#           (softmax): Softmax(dim=-1)
#           (dropout): Dropout(p=0.1, inplace=False)
#           (final_linear): Linear(in_features=256, out_features=256, bias=True)
#         )
#         (feed_forward): PositionwiseFeedForward(
#           (w_1): Linear(in_features=256, out_features=2048, bias=True)
#           (w_2): Linear(in_features=2048, out_features=256, bias=True)
#           (layer_norm): LayerNorm((256,), eps=1e-06, elementwise_affine=True)
#           (dropout_1): Dropout(p=0.1, inplace=False)
#           (relu): ReLU()
#           (dropout_2): Dropout(p=0.1, inplace=False)
#         )
#         (layer_norm): LayerNorm((256,), eps=1e-06, elementwise_affine=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#       (2): TransformerEncoderLayer(
#         (self_attn): MultiHeadedAttention(
#           (linear_keys): Linear(in_features=256, out_features=256, bias=True)
#           (linear_values): Linear(in_features=256, out_features=256, bias=True)
#           (linear_query): Linear(in_features=256, out_features=256, bias=True)
#           (softmax): Softmax(dim=-1)
#           (dropout): Dropout(p=0.1, inplace=False)
#           (final_linear): Linear(in_features=256, out_features=256, bias=True)
#         )
#         (feed_forward): PositionwiseFeedForward(
#           (w_1): Linear(in_features=256, out_features=2048, bias=True)
#           (w_2): Linear(in_features=2048, out_features=256, bias=True)
#           (layer_norm): LayerNorm((256,), eps=1e-06, elementwise_affine=True)
#           (dropout_1): Dropout(p=0.1, inplace=False)
#           (relu): ReLU()
#           (dropout_2): Dropout(p=0.1, inplace=False)
#         )
#         (layer_norm): LayerNorm((256,), eps=1e-06, elementwise_affine=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#       (3): TransformerEncoderLayer(
#         (self_attn): MultiHeadedAttention(
#           (linear_keys): Linear(in_features=256, out_features=256, bias=True)
#           (linear_values): Linear(in_features=256, out_features=256, bias=True)
#           (linear_query): Linear(in_features=256, out_features=256, bias=True)
#           (softmax): Softmax(dim=-1)
#           (dropout): Dropout(p=0.1, inplace=False)
#           (final_linear): Linear(in_features=256, out_features=256, bias=True)
#         )
#         (feed_forward): PositionwiseFeedForward(
#           (w_1): Linear(in_features=256, out_features=2048, bias=True)
#           (w_2): Linear(in_features=2048, out_features=256, bias=True)
#           (layer_norm): LayerNorm((256,), eps=1e-06, elementwise_affine=True)
#           (dropout_1): Dropout(p=0.1, inplace=False)
#           (relu): ReLU()
#           (dropout_2): Dropout(p=0.1, inplace=False)
#         )
#         (layer_norm): LayerNorm((256,), eps=1e-06, elementwise_affine=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#       (4): TransformerEncoderLayer(
#         (self_attn): MultiHeadedAttention(
#           (linear_keys): Linear(in_features=256, out_features=256, bias=True)
#           (linear_values): Linear(in_features=256, out_features=256, bias=True)
#           (linear_query): Linear(in_features=256, out_features=256, bias=True)
#           (softmax): Softmax(dim=-1)
#           (dropout): Dropout(p=0.1, inplace=False)
#           (final_linear): Linear(in_features=256, out_features=256, bias=True)
#         )
#         (feed_forward): PositionwiseFeedForward(
#           (w_1): Linear(in_features=256, out_features=2048, bias=True)
#           (w_2): Linear(in_features=2048, out_features=256, bias=True)
#           (layer_norm): LayerNorm((256,), eps=1e-06, elementwise_affine=True)
#           (dropout_1): Dropout(p=0.1, inplace=False)
#           (relu): ReLU()
#           (dropout_2): Dropout(p=0.1, inplace=False)
#         )
#         (layer_norm): LayerNorm((256,), eps=1e-06, elementwise_affine=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#       (5): TransformerEncoderLayer(
#         (self_attn): MultiHeadedAttention(
#           (linear_keys): Linear(in_features=256, out_features=256, bias=True)
#           (linear_values): Linear(in_features=256, out_features=256, bias=True)
#           (linear_query): Linear(in_features=256, out_features=256, bias=True)
#           (softmax): Softmax(dim=-1)
#           (dropout): Dropout(p=0.1, inplace=False)
#           (final_linear): Linear(in_features=256, out_features=256, bias=True)
#         )
#         (feed_forward): PositionwiseFeedForward(
#           (w_1): Linear(in_features=256, out_features=2048, bias=True)
#           (w_2): Linear(in_features=2048, out_features=256, bias=True)
#           (layer_norm): LayerNorm((256,), eps=1e-06, elementwise_affine=True)
#           (dropout_1): Dropout(p=0.1, inplace=False)
#           (relu): ReLU()
#           (dropout_2): Dropout(p=0.1, inplace=False)
#         )
#         (layer_norm): LayerNorm((256,), eps=1e-06, elementwise_affine=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#     )
#     (layer_norm): LayerNorm((256,), eps=1e-06, elementwise_affine=True)
#   )
#   (decoder): TransformerDecoder(
#     (embeddings): Embeddings(
#       (make_embedding): Sequential(
#         (emb_luts): Elementwise(
#           (0): Embedding(50004, 256, padding_idx=1)
#         )
#         (pe): PositionalEncoding(
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#     )
#     (transformer_layers): ModuleList(
#       (0): TransformerDecoderLayer(
#         (self_attn): MultiHeadedAttention(
#           (linear_keys): Linear(in_features=256, out_features=256, bias=True)
#           (linear_values): Linear(in_features=256, out_features=256, bias=True)
#           (linear_query): Linear(in_features=256, out_features=256, bias=True)
#           (softmax): Softmax(dim=-1)
#           (dropout): Dropout(p=0.1, inplace=False)
#           (final_linear): Linear(in_features=256, out_features=256, bias=True)
#         )
#         (context_attn): MultiHeadedAttention(
#           (linear_keys): Linear(in_features=256, out_features=256, bias=True)
#           (linear_values): Linear(in_features=256, out_features=256, bias=True)
#           (linear_query): Linear(in_features=256, out_features=256, bias=True)
#           (softmax): Softmax(dim=-1)
#           (dropout): Dropout(p=0.1, inplace=False)
#           (final_linear): Linear(in_features=256, out_features=256, bias=True)
#         )
#         (feed_forward): PositionwiseFeedForward(
#           (w_1): Linear(in_features=256, out_features=2048, bias=True)
#           (w_2): Linear(in_features=2048, out_features=256, bias=True)
#           (layer_norm): LayerNorm((256,), eps=1e-06, elementwise_affine=True)
#           (dropout_1): Dropout(p=0.1, inplace=False)
#           (relu): ReLU()
#           (dropout_2): Dropout(p=0.1, inplace=False)
#         )
#         (layer_norm_1): LayerNorm((256,), eps=1e-06, elementwise_affine=True)
#         (layer_norm_2): LayerNorm((256,), eps=1e-06, elementwise_affine=True)
#         (drop): Dropout(p=0.1, inplace=False)
#       )
#       (1): TransformerDecoderLayer(
#         (self_attn): MultiHeadedAttention(
#           (linear_keys): Linear(in_features=256, out_features=256, bias=True)
#           (linear_values): Linear(in_features=256, out_features=256, bias=True)
#           (linear_query): Linear(in_features=256, out_features=256, bias=True)
#           (softmax): Softmax(dim=-1)
#           (dropout): Dropout(p=0.1, inplace=False)
#           (final_linear): Linear(in_features=256, out_features=256, bias=True)
#         )
#         (context_attn): MultiHeadedAttention(
#           (linear_keys): Linear(in_features=256, out_features=256, bias=True)
#           (linear_values): Linear(in_features=256, out_features=256, bias=True)
#           (linear_query): Linear(in_features=256, out_features=256, bias=True)
#           (softmax): Softmax(dim=-1)
#           (dropout): Dropout(p=0.1, inplace=False)
#           (final_linear): Linear(in_features=256, out_features=256, bias=True)
#         )
#         (feed_forward): PositionwiseFeedForward(
#           (w_1): Linear(in_features=256, out_features=2048, bias=True)
#           (w_2): Linear(in_features=2048, out_features=256, bias=True)
#           (layer_norm): LayerNorm((256,), eps=1e-06, elementwise_affine=True)
#           (dropout_1): Dropout(p=0.1, inplace=False)
#           (relu): ReLU()
#           (dropout_2): Dropout(p=0.1, inplace=False)
#         )
#         (layer_norm_1): LayerNorm((256,), eps=1e-06, elementwise_affine=True)
#         (layer_norm_2): LayerNorm((256,), eps=1e-06, elementwise_affine=True)
#         (drop): Dropout(p=0.1, inplace=False)
#       )
#       (2): TransformerDecoderLayer(
#         (self_attn): MultiHeadedAttention(
#           (linear_keys): Linear(in_features=256, out_features=256, bias=True)
#           (linear_values): Linear(in_features=256, out_features=256, bias=True)
#           (linear_query): Linear(in_features=256, out_features=256, bias=True)
#           (softmax): Softmax(dim=-1)
#           (dropout): Dropout(p=0.1, inplace=False)
#           (final_linear): Linear(in_features=256, out_features=256, bias=True)
#         )
#         (context_attn): MultiHeadedAttention(
#           (linear_keys): Linear(in_features=256, out_features=256, bias=True)
#           (linear_values): Linear(in_features=256, out_features=256, bias=True)
#           (linear_query): Linear(in_features=256, out_features=256, bias=True)
#           (softmax): Softmax(dim=-1)
#           (dropout): Dropout(p=0.1, inplace=False)
#           (final_linear): Linear(in_features=256, out_features=256, bias=True)
#         )
#         (feed_forward): PositionwiseFeedForward(
#           (w_1): Linear(in_features=256, out_features=2048, bias=True)
#           (w_2): Linear(in_features=2048, out_features=256, bias=True)
#           (layer_norm): LayerNorm((256,), eps=1e-06, elementwise_affine=True)
#           (dropout_1): Dropout(p=0.1, inplace=False)
#           (relu): ReLU()
#           (dropout_2): Dropout(p=0.1, inplace=False)
#         )
#         (layer_norm_1): LayerNorm((256,), eps=1e-06, elementwise_affine=True)
#         (layer_norm_2): LayerNorm((256,), eps=1e-06, elementwise_affine=True)
#         (drop): Dropout(p=0.1, inplace=False)
#       )
#       (3): TransformerDecoderLayer(
#         (self_attn): MultiHeadedAttention(
#           (linear_keys): Linear(in_features=256, out_features=256, bias=True)
#           (linear_values): Linear(in_features=256, out_features=256, bias=True)
#           (linear_query): Linear(in_features=256, out_features=256, bias=True)
#           (softmax): Softmax(dim=-1)
#           (dropout): Dropout(p=0.1, inplace=False)
#           (final_linear): Linear(in_features=256, out_features=256, bias=True)
#         )
#         (context_attn): MultiHeadedAttention(
#           (linear_keys): Linear(in_features=256, out_features=256, bias=True)
#           (linear_values): Linear(in_features=256, out_features=256, bias=True)
#           (linear_query): Linear(in_features=256, out_features=256, bias=True)
#           (softmax): Softmax(dim=-1)
#           (dropout): Dropout(p=0.1, inplace=False)
#           (final_linear): Linear(in_features=256, out_features=256, bias=True)
#         )
#         (feed_forward): PositionwiseFeedForward(
#           (w_1): Linear(in_features=256, out_features=2048, bias=True)
#           (w_2): Linear(in_features=2048, out_features=256, bias=True)
#           (layer_norm): LayerNorm((256,), eps=1e-06, elementwise_affine=True)
#           (dropout_1): Dropout(p=0.1, inplace=False)
#           (relu): ReLU()
#           (dropout_2): Dropout(p=0.1, inplace=False)
#         )
#         (layer_norm_1): LayerNorm((256,), eps=1e-06, elementwise_affine=True)
#         (layer_norm_2): LayerNorm((256,), eps=1e-06, elementwise_affine=True)
#         (drop): Dropout(p=0.1, inplace=False)
#       )
#       (4): TransformerDecoderLayer(
#         (self_attn): MultiHeadedAttention(
#           (linear_keys): Linear(in_features=256, out_features=256, bias=True)
#           (linear_values): Linear(in_features=256, out_features=256, bias=True)
#           (linear_query): Linear(in_features=256, out_features=256, bias=True)
#           (softmax): Softmax(dim=-1)
#           (dropout): Dropout(p=0.1, inplace=False)
#           (final_linear): Linear(in_features=256, out_features=256, bias=True)
#         )
#         (context_attn): MultiHeadedAttention(
#           (linear_keys): Linear(in_features=256, out_features=256, bias=True)
#           (linear_values): Linear(in_features=256, out_features=256, bias=True)
#           (linear_query): Linear(in_features=256, out_features=256, bias=True)
#           (softmax): Softmax(dim=-1)
#           (dropout): Dropout(p=0.1, inplace=False)
#           (final_linear): Linear(in_features=256, out_features=256, bias=True)
#         )
#         (feed_forward): PositionwiseFeedForward(
#           (w_1): Linear(in_features=256, out_features=2048, bias=True)
#           (w_2): Linear(in_features=2048, out_features=256, bias=True)
#           (layer_norm): LayerNorm((256,), eps=1e-06, elementwise_affine=True)
#           (dropout_1): Dropout(p=0.1, inplace=False)
#           (relu): ReLU()
#           (dropout_2): Dropout(p=0.1, inplace=False)
#         )
#         (layer_norm_1): LayerNorm((256,), eps=1e-06, elementwise_affine=True)
#         (layer_norm_2): LayerNorm((256,), eps=1e-06, elementwise_affine=True)
#         (drop): Dropout(p=0.1, inplace=False)
#       )
#       (5): TransformerDecoderLayer(
#         (self_attn): MultiHeadedAttention(
#           (linear_keys): Linear(in_features=256, out_features=256, bias=True)
#           (linear_values): Linear(in_features=256, out_features=256, bias=True)
#           (linear_query): Linear(in_features=256, out_features=256, bias=True)
#           (softmax): Softmax(dim=-1)
#           (dropout): Dropout(p=0.1, inplace=False)
#           (final_linear): Linear(in_features=256, out_features=256, bias=True)
#         )
#         (context_attn): MultiHeadedAttention(
#           (linear_keys): Linear(in_features=256, out_features=256, bias=True)
#           (linear_values): Linear(in_features=256, out_features=256, bias=True)
#           (linear_query): Linear(in_features=256, out_features=256, bias=True)
#           (softmax): Softmax(dim=-1)
#           (dropout): Dropout(p=0.1, inplace=False)
#           (final_linear): Linear(in_features=256, out_features=256, bias=True)
#         )
#         (feed_forward): PositionwiseFeedForward(
#           (w_1): Linear(in_features=256, out_features=2048, bias=True)
#           (w_2): Linear(in_features=2048, out_features=256, bias=True)
#           (layer_norm): LayerNorm((256,), eps=1e-06, elementwise_affine=True)
#           (dropout_1): Dropout(p=0.1, inplace=False)
#           (relu): ReLU()
#           (dropout_2): Dropout(p=0.1, inplace=False)
#         )
#         (layer_norm_1): LayerNorm((256,), eps=1e-06, elementwise_affine=True)
#         (layer_norm_2): LayerNorm((256,), eps=1e-06, elementwise_affine=True)
#         (drop): Dropout(p=0.1, inplace=False)
#       )
#     )
#     (layer_norm): LayerNorm((256,), eps=1e-06, elementwise_affine=True)
#   )
#   (generator): Sequential(
#     (0): Linear(in_features=256, out_features=50004, bias=True)
#     (1): Cast()
#     (2): LogSoftmax()
#   )
# )
# [2020-03-26 12:25:49,108 INFO] encoder: 20691456
# [2020-03-26 12:25:49,108 INFO] decoder: 35125076
# [2020-03-26 12:25:49,108 INFO] * number of parameters: 55816532
# [2020-03-26 12:25:49,117 INFO] Starting training on GPU: [0]
# [2020-03-26 12:25:49,117 INFO] Start training loop and validate every 10000 steps...
# [2020-03-26 12:25:49,117 INFO] Loading dataset from nmt_subs_en_vi.train.0.pt
# [2020-03-26 12:25:58,894 INFO] number of examples: 986019
# [2020-03-26 12:27:20,827 INFO] Step 50/100000; acc:   5.92; ppl: 11543.40; xent: 9.35; lr: 0.00001; 2775/4105 tok/s;     92 sec
# [2020-03-26 12:28:30,696 INFO] Step 100/100000; acc:  11.45; ppl: 9366.79; xent: 9.14; lr: 0.00002; 4000/5389 tok/s;    162 sec
# [2020-03-26 12:29:38,511 INFO] Step 150/100000; acc:  12.37; ppl: 6888.31; xent: 8.84; lr: 0.00003; 3868/5407 tok/s;    229 sec
# [2020-03-26 12:30:48,387 INFO] Step 200/100000; acc:  12.52; ppl: 4523.11; xent: 8.42; lr: 0.00004; 3809/5440 tok/s;    299 sec
# [2020-03-26 12:31:55,701 INFO] Step 250/100000; acc:  13.72; ppl: 2702.20; xent: 7.90; lr: 0.00004; 3997/5402 tok/s;    367 sec
# [2020-03-26 12:33:04,115 INFO] Step 300/100000; acc:  13.15; ppl: 1583.41; xent: 7.37; lr: 0.00005; 3876/5365 tok/s;    435 sec
# [2020-03-26 12:34:12,500 INFO] Step 350/100000; acc:  12.99; ppl: 983.43; xent: 6.89; lr: 0.00006; 3862/5360 tok/s;    503 sec
# [2020-03-26 12:35:21,566 INFO] Step 400/100000; acc:  13.21; ppl: 661.56; xent: 6.49; lr: 0.00007; 3859/5447 tok/s;    572 sec
# [2020-03-26 12:36:28,515 INFO] Step 450/100000; acc:  13.69; ppl: 503.08; xent: 6.22; lr: 0.00008; 3971/5296 tok/s;    639 sec
# [2020-03-26 12:37:36,837 INFO] Step 500/100000; acc:  12.36; ppl: 429.06; xent: 6.06; lr: 0.00009; 4002/5355 tok/s;    708 sec
# [2020-03-26 12:38:44,748 INFO] Step 550/100000; acc:  14.15; ppl: 363.12; xent: 5.89; lr: 0.00010; 4120/5366 tok/s;    776 sec
# [2020-03-26 12:39:54,037 INFO] Step 600/100000; acc:  12.78; ppl: 332.46; xent: 5.81; lr: 0.00010; 3968/5381 tok/s;    845 sec
# [2020-03-26 12:41:02,360 INFO] Step 650/100000; acc:  14.27; ppl: 275.91; xent: 5.62; lr: 0.00011; 3996/5342 tok/s;    913 sec
# [2020-03-26 12:42:10,525 INFO] Step 700/100000; acc:  14.34; ppl: 258.36; xent: 5.55; lr: 0.00012; 3916/5371 tok/s;    981 sec
# [2020-03-26 12:43:18,883 INFO] Step 750/100000; acc:  15.26; ppl: 238.62; xent: 5.47; lr: 0.00013; 3759/5417 tok/s;   1050 sec
# [2020-03-26 12:44:27,343 INFO] Step 800/100000; acc:  16.00; ppl: 212.24; xent: 5.36; lr: 0.00014; 4078/5363 tok/s;   1118 sec
# [2020-03-26 12:45:37,558 INFO] Step 850/100000; acc:  14.75; ppl: 218.74; xent: 5.39; lr: 0.00015; 3939/5430 tok/s;   1188 sec
# [2020-03-26 12:46:45,452 INFO] Step 900/100000; acc:  16.52; ppl: 197.29; xent: 5.28; lr: 0.00016; 3909/5428 tok/s;   1256 sec
# [2020-03-26 12:47:53,766 INFO] Step 950/100000; acc:  17.20; ppl: 182.11; xent: 5.20; lr: 0.00017; 3988/5358 tok/s;   1325 sec
# [2020-03-26 12:49:02,247 INFO] Step 1000/100000; acc:  18.05; ppl: 172.88; xent: 5.15; lr: 0.00017; 3867/5462 tok/s;   1393 sec
# [2020-03-26 12:50:10,014 INFO] Step 1050/100000; acc:  18.04; ppl: 164.52; xent: 5.10; lr: 0.00018; 3850/5386 tok/s;   1461 sec
# [2020-03-26 12:50:32,300 INFO] Loading dataset from nmt_subs_en_vi.train.1.pt
# [2020-03-26 12:50:32,319 INFO] number of examples: 3500
# [2020-03-26 12:50:40,762 INFO] Loading dataset from nmt_subs_en_vi.train.0.pt
# [2020-03-26 12:50:49,927 INFO] number of examples: 986019
# [2020-03-26 12:51:38,652 INFO] Step 1100/100000; acc:  17.35; ppl: 165.79; xent: 5.11; lr: 0.00019; 2880/4154 tok/s;   1550 sec
# [2020-03-26 12:52:47,038 INFO] Step 1150/100000; acc:  18.41; ppl: 149.05; xent: 5.00; lr: 0.00020; 3901/5418 tok/s;   1618 sec
# [2020-03-26 12:53:56,214 INFO] Step 1200/100000; acc:  17.88; ppl: 148.24; xent: 5.00; lr: 0.00021; 3917/5375 tok/s;   1687 sec
# [2020-03-26 12:55:05,523 INFO] Step 1250/100000; acc:  20.09; ppl: 125.27; xent: 4.83; lr: 0.00022; 3822/5425 tok/s;   1756 sec
# [2020-03-26 12:56:14,033 INFO] Step 1300/100000; acc:  21.45; ppl: 114.83; xent: 4.74; lr: 0.00023; 3881/5413 tok/s;   1825 sec
# [2020-03-26 12:57:21,338 INFO] Step 1350/100000; acc:  22.56; ppl: 104.39; xent: 4.65; lr: 0.00024; 3992/5330 tok/s;   1892 sec
# [2020-03-26 12:58:30,390 INFO] Step 1400/100000; acc:  21.51; ppl: 108.81; xent: 4.69; lr: 0.00024; 3892/5314 tok/s;   1961 sec
# [2020-03-26 12:59:39,657 INFO] Step 1450/100000; acc:  22.95; ppl: 100.03; xent: 4.61; lr: 0.00025; 3779/5445 tok/s;   2031 sec
# [2020-03-26 13:00:47,906 INFO] Step 1500/100000; acc:  24.06; ppl: 92.18; xent: 4.52; lr: 0.00026; 3799/5408 tok/s;   2099 sec
# [2020-03-26 13:01:55,154 INFO] Step 1550/100000; acc:  25.46; ppl: 84.37; xent: 4.44; lr: 0.00027; 4032/5344 tok/s;   2166 sec
# [2020-03-26 13:03:03,080 INFO] Step 1600/100000; acc:  24.96; ppl: 84.94; xent: 4.44; lr: 0.00028; 4141/5366 tok/s;   2234 sec
# [2020-03-26 13:04:11,081 INFO] Step 1650/100000; acc:  25.71; ppl: 80.32; xent: 4.39; lr: 0.00029; 4025/5418 tok/s;   2302 sec
# [2020-03-26 13:05:19,935 INFO] Step 1700/100000; acc:  26.27; ppl: 75.32; xent: 4.32; lr: 0.00030; 4053/5367 tok/s;   2371 sec
# [2020-03-26 13:06:27,685 INFO] Step 1750/100000; acc:  27.64; ppl: 69.44; xent: 4.24; lr: 0.00031; 3969/5382 tok/s;   2439 sec
# [2020-03-26 13:07:35,724 INFO] Step 1800/100000; acc:  28.45; ppl: 66.66; xent: 4.20; lr: 0.00031; 3754/5456 tok/s;   2507 sec
# [2020-03-26 13:08:44,028 INFO] Step 1850/100000; acc:  28.78; ppl: 62.48; xent: 4.13; lr: 0.00032; 4066/5299 tok/s;   2575 sec
# [2020-03-26 13:09:53,119 INFO] Step 1900/100000; acc:  29.99; ppl: 56.96; xent: 4.04; lr: 0.00033; 3996/5411 tok/s;   2644 sec
# [2020-03-26 13:11:02,767 INFO] Step 1950/100000; acc:  30.03; ppl: 55.80; xent: 4.02; lr: 0.00034; 3796/5437 tok/s;   2714 sec
# [2020-03-26 13:12:11,485 INFO] Step 2000/100000; acc:  31.30; ppl: 50.33; xent: 3.92; lr: 0.00035; 4001/5369 tok/s;   2782 sec
# [2020-03-26 13:13:19,503 INFO] Step 2050/100000; acc:  31.98; ppl: 49.22; xent: 3.90; lr: 0.00036; 3916/5395 tok/s;   2850 sec
# [2020-03-26 13:14:27,991 INFO] Step 2100/100000; acc:  32.11; ppl: 48.28; xent: 3.88; lr: 0.00037; 3951/5346 tok/s;   2919 sec
# [2020-03-26 13:15:20,538 INFO] Loading dataset from nmt_subs_en_vi.train.1.pt
# [2020-03-26 13:15:20,557 INFO] number of examples: 3500
# [2020-03-26 13:15:28,426 INFO] Loading dataset from nmt_subs_en_vi.train.0.pt
# [2020-03-26 13:15:38,247 INFO] number of examples: 986019
# [2020-03-26 13:15:56,466 INFO] Step 2150/100000; acc:  32.84; ppl: 45.10; xent: 3.81; lr: 0.00038; 2853/4078 tok/s;   3007 sec
# [2020-03-26 13:17:05,269 INFO] Step 2200/100000; acc:  31.71; ppl: 48.10; xent: 3.87; lr: 0.00038; 3683/5487 tok/s;   3076 sec
# [2020-03-26 13:18:15,680 INFO] Step 2250/100000; acc:  32.03; ppl: 45.71; xent: 3.82; lr: 0.00039; 3972/5342 tok/s;   3147 sec
# [2020-03-26 13:19:24,439 INFO] Step 2300/100000; acc:  33.57; ppl: 41.85; xent: 3.73; lr: 0.00040; 3823/5402 tok/s;   3215 sec
# [2020-03-26 13:20:34,405 INFO] Step 2350/100000; acc:  35.13; ppl: 37.01; xent: 3.61; lr: 0.00041; 3751/5451 tok/s;   3285 sec
# [2020-03-26 13:21:41,054 INFO] Step 2400/100000; acc:  36.24; ppl: 34.72; xent: 3.55; lr: 0.00042; 4042/5380 tok/s;   3352 sec
# [2020-03-26 13:22:49,548 INFO] Step 2450/100000; acc:  35.53; ppl: 35.43; xent: 3.57; lr: 0.00043; 3907/5365 tok/s;   3420 sec
# [2020-03-26 13:23:58,340 INFO] Step 2500/100000; acc:  35.73; ppl: 34.65; xent: 3.55; lr: 0.00044; 3846/5374 tok/s;   3489 sec
# [2020-03-26 13:25:06,211 INFO] Step 2550/100000; acc:  37.58; ppl: 30.77; xent: 3.43; lr: 0.00045; 3903/5448 tok/s;   3557 sec
# [2020-03-26 13:26:13,416 INFO] Step 2600/100000; acc:  36.85; ppl: 31.80; xent: 3.46; lr: 0.00045; 3967/5332 tok/s;   3624 sec
# [2020-03-26 13:27:21,591 INFO] Step 2650/100000; acc:  36.32; ppl: 32.55; xent: 3.48; lr: 0.00046; 4040/5359 tok/s;   3692 sec
# [2020-03-26 13:28:29,637 INFO] Step 2700/100000; acc:  37.10; ppl: 30.26; xent: 3.41; lr: 0.00047; 4070/5373 tok/s;   3761 sec
# [2020-03-26 13:29:38,904 INFO] Step 2750/100000; acc:  36.52; ppl: 30.64; xent: 3.42; lr: 0.00048; 4008/5410 tok/s;   3830 sec
# [2020-03-26 13:30:46,302 INFO] Step 2800/100000; acc:  38.76; ppl: 26.59; xent: 3.28; lr: 0.00049; 3980/5375 tok/s;   3897 sec
# [2020-03-26 13:31:54,311 INFO] Step 2850/100000; acc:  37.57; ppl: 28.87; xent: 3.36; lr: 0.00050; 3913/5404 tok/s;   3965 sec
# [2020-03-26 13:33:02,524 INFO] Step 2900/100000; acc:  37.90; ppl: 28.12; xent: 3.34; lr: 0.00051; 3890/5378 tok/s;   4033 sec
# [2020-03-26 13:34:10,929 INFO] Step 2950/100000; acc:  39.75; ppl: 24.29; xent: 3.19; lr: 0.00052; 4060/5341 tok/s;   4102 sec
# [2020-03-26 13:35:21,540 INFO] Step 3000/100000; acc:  38.12; ppl: 26.72; xent: 3.29; lr: 0.00052; 3908/5424 tok/s;   4172 sec
# [2020-03-26 13:36:29,654 INFO] Step 3050/100000; acc:  39.64; ppl: 24.32; xent: 3.19; lr: 0.00053; 3872/5452 tok/s;   4241 sec
# [2020-03-26 13:37:37,755 INFO] Step 3100/100000; acc:  40.33; ppl: 23.10; xent: 3.14; lr: 0.00054; 4024/5355 tok/s;   4309 sec
# [2020-03-26 13:38:45,991 INFO] Step 3150/100000; acc:  39.89; ppl: 23.91; xent: 3.17; lr: 0.00055; 3927/5412 tok/s;   4377 sec
# [2020-03-26 13:39:54,909 INFO] Step 3200/100000; acc:  39.56; ppl: 24.12; xent: 3.18; lr: 0.00056; 3748/5424 tok/s;   4446 sec
# [2020-03-26 13:40:07,010 INFO] Loading dataset from nmt_subs_en_vi.train.1.pt
# [2020-03-26 13:40:08,932 INFO] number of examples: 3500
# [2020-03-26 13:40:16,848 INFO] Loading dataset from nmt_subs_en_vi.train.0.pt
# [2020-03-26 13:40:26,278 INFO] number of examples: 986019
# [2020-03-26 13:41:24,870 INFO] Step 3250/100000; acc:  41.42; ppl: 21.43; xent: 3.06; lr: 0.00057; 2797/4062 tok/s;   4536 sec
# [2020-03-26 13:42:33,947 INFO] Step 3300/100000; acc:  38.79; ppl: 24.92; xent: 3.22; lr: 0.00058; 3894/5394 tok/s;   4605 sec
# [2020-03-26 13:43:42,670 INFO] Step 3350/100000; acc:  38.96; ppl: 24.68; xent: 3.21; lr: 0.00059; 3900/5382 tok/s;   4674 sec
# [2020-03-26 13:44:52,536 INFO] Step 3400/100000; acc:  41.59; ppl: 20.59; xent: 3.02; lr: 0.00059; 3821/5418 tok/s;   4743 sec
# [2020-03-26 13:46:00,673 INFO] Step 3450/100000; acc:  42.44; ppl: 19.57; xent: 2.97; lr: 0.00060; 3856/5415 tok/s;   4812 sec
# [2020-03-26 13:47:07,915 INFO] Step 3500/100000; acc:  42.58; ppl: 19.29; xent: 2.96; lr: 0.00061; 3989/5350 tok/s;   4879 sec
# [2020-03-26 13:48:16,799 INFO] Step 3550/100000; acc:  41.50; ppl: 20.50; xent: 3.02; lr: 0.00062; 3893/5324 tok/s;   4948 sec
# [2020-03-26 13:49:26,438 INFO] Step 3600/100000; acc:  42.15; ppl: 19.44; xent: 2.97; lr: 0.00063; 3842/5422 tok/s;   5017 sec
# [2020-03-26 13:50:34,213 INFO] Step 3650/100000; acc:  42.86; ppl: 18.77; xent: 2.93; lr: 0.00064; 3871/5343 tok/s;   5085 sec
# [2020-03-26 13:51:41,323 INFO] Step 3700/100000; acc:  42.64; ppl: 19.07; xent: 2.95; lr: 0.00065; 3987/5367 tok/s;   5152 sec
# [2020-03-26 13:52:49,934 INFO] Step 3750/100000; acc:  41.98; ppl: 19.10; xent: 2.95; lr: 0.00066; 4156/5358 tok/s;   5221 sec
# [2020-03-26 13:53:57,957 INFO] Step 3800/100000; acc:  41.90; ppl: 19.38; xent: 2.96; lr: 0.00066; 3956/5421 tok/s;   5289 sec
# [2020-03-26 13:55:07,067 INFO] Step 3850/100000; acc:  42.45; ppl: 18.18; xent: 2.90; lr: 0.00067; 3999/5373 tok/s;   5358 sec
# [2020-03-26 13:56:14,982 INFO] Step 3900/100000; acc:  43.08; ppl: 17.73; xent: 2.88; lr: 0.00068; 3974/5374 tok/s;   5426 sec
# [2020-03-26 13:57:23,054 INFO] Step 3950/100000; acc:  43.01; ppl: 18.13; xent: 2.90; lr: 0.00069; 3758/5452 tok/s;   5494 sec
# [2020-03-26 13:58:31,292 INFO] Step 4000/100000; acc:  43.63; ppl: 17.04; xent: 2.84; lr: 0.00070; 4069/5298 tok/s;   5562 sec
# [2020-03-26 13:59:40,828 INFO] Step 4050/100000; acc:  43.68; ppl: 16.80; xent: 2.82; lr: 0.00071; 4023/5382 tok/s;   5632 sec
# [2020-03-26 14:00:49,701 INFO] Step 4100/100000; acc:  42.95; ppl: 17.80; xent: 2.88; lr: 0.00072; 3802/5450 tok/s;   5701 sec
# [2020-03-26 14:01:57,936 INFO] Step 4150/100000; acc:  44.52; ppl: 15.82; xent: 2.76; lr: 0.00073; 4046/5394 tok/s;   5769 sec
# [2020-03-26 14:03:06,171 INFO] Step 4200/100000; acc:  43.34; ppl: 17.27; xent: 2.85; lr: 0.00073; 3882/5430 tok/s;   5837 sec
# [2020-03-26 14:04:13,705 INFO] Step 4250/100000; acc:  44.44; ppl: 16.29; xent: 2.79; lr: 0.00074; 3883/5406 tok/s;   5905 sec
# [2020-03-26 14:04:56,833 INFO] Loading dataset from nmt_subs_en_vi.train.1.pt
# [2020-03-26 14:04:56,852 INFO] number of examples: 3500
# [2020-03-26 14:05:04,657 INFO] Loading dataset from nmt_subs_en_vi.train.0.pt
# [2020-03-26 14:05:14,784 INFO] number of examples: 986019
# [2020-03-26 14:05:42,240 INFO] Step 4300/100000; acc:  44.85; ppl: 15.67; xent: 2.75; lr: 0.00075; 2907/4103 tok/s;   5993 sec
# [2020-03-26 14:06:50,813 INFO] Step 4350/100000; acc:  42.36; ppl: 18.29; xent: 2.91; lr: 0.00076; 3702/5479 tok/s;   6062 sec
# [2020-03-26 14:08:00,992 INFO] Step 4400/100000; acc:  43.15; ppl: 17.01; xent: 2.83; lr: 0.00077; 4026/5332 tok/s;   6132 sec
# [2020-03-26 14:09:09,751 INFO] Step 4450/100000; acc:  44.25; ppl: 16.16; xent: 2.78; lr: 0.00078; 3784/5433 tok/s;   6201 sec
# [2020-03-26 14:10:18,875 INFO] Step 4500/100000; acc:  45.15; ppl: 15.04; xent: 2.71; lr: 0.00079; 3844/5451 tok/s;   6270 sec
# [2020-03-26 14:11:25,600 INFO] Step 4550/100000; acc:  45.56; ppl: 14.78; xent: 2.69; lr: 0.00080; 4006/5342 tok/s;   6336 sec
# [2020-03-26 14:12:34,450 INFO] Step 4600/100000; acc:  45.81; ppl: 14.43; xent: 2.67; lr: 0.00080; 3898/5428 tok/s;   6405 sec
# [2020-03-26 14:13:42,855 INFO] Step 4650/100000; acc:  44.75; ppl: 15.41; xent: 2.73; lr: 0.00081; 3848/5386 tok/s;   6474 sec
# [2020-03-26 14:14:51,183 INFO] Step 4700/100000; acc:  45.81; ppl: 14.41; xent: 2.67; lr: 0.00082; 3902/5411 tok/s;   6542 sec
# [2020-03-26 14:15:58,425 INFO] Step 4750/100000; acc:  45.47; ppl: 14.64; xent: 2.68; lr: 0.00083; 3952/5330 tok/s;   6609 sec
# [2020-03-26 14:17:06,392 INFO] Step 4800/100000; acc:  44.76; ppl: 15.14; xent: 2.72; lr: 0.00084; 4135/5330 tok/s;   6677 sec
# [2020-03-26 14:18:15,099 INFO] Step 4850/100000; acc:  44.91; ppl: 14.91; xent: 2.70; lr: 0.00085; 3963/5414 tok/s;   6746 sec
# [2020-03-26 14:19:23,931 INFO] Step 4900/100000; acc:  45.23; ppl: 14.39; xent: 2.67; lr: 0.00086; 4072/5395 tok/s;   6815 sec
# [2020-03-26 14:20:32,041 INFO] Step 4950/100000; acc:  45.79; ppl: 13.96; xent: 2.64; lr: 0.00086; 3980/5341 tok/s;   6883 sec
# [2020-03-26 14:21:39,880 INFO] Step 5000/100000; acc:  45.14; ppl: 14.87; xent: 2.70; lr: 0.00087; 3817/5414 tok/s;   6951 sec
# [2020-03-26 14:21:41,341 INFO] Saving checkpoint transformer_step_5000.pt
# [2020-03-26 14:22:53,045 INFO] Step 5050/100000; acc:  45.26; ppl: 14.45; xent: 2.67; lr: 0.00088; 3682/5024 tok/s;   7024 sec
# [2020-03-26 14:24:01,170 INFO] Step 5100/100000; acc:  47.04; ppl: 12.91; xent: 2.56; lr: 0.00089; 4117/5351 tok/s;   7092 sec
# [2020-03-26 14:25:11,617 INFO] Step 5150/100000; acc:  45.07; ppl: 14.52; xent: 2.68; lr: 0.00090; 3824/5463 tok/s;   7162 sec
# [2020-03-26 14:26:19,612 INFO] Step 5200/100000; acc:  46.18; ppl: 13.61; xent: 2.61; lr: 0.00091; 3899/5454 tok/s;   7230 sec
# [2020-03-26 14:27:27,471 INFO] Step 5250/100000; acc:  46.41; ppl: 13.48; xent: 2.60; lr: 0.00092; 4021/5352 tok/s;   7298 sec
# [2020-03-26 14:28:35,410 INFO] Step 5300/100000; acc:  46.75; ppl: 13.32; xent: 2.59; lr: 0.00093; 3903/5446 tok/s;   7366 sec
# [2020-03-26 14:29:44,020 INFO] Step 5350/100000; acc:  46.10; ppl: 13.67; xent: 2.62; lr: 0.00093; 3814/5403 tok/s;   7435 sec
# [2020-03-26 14:29:47,016 INFO] Loading dataset from nmt_subs_en_vi.train.1.pt
# [2020-03-26 14:29:47,036 INFO] number of examples: 3500
# [2020-03-26 14:29:54,851 INFO] Loading dataset from nmt_subs_en_vi.train.0.pt
# [2020-03-26 14:30:05,925 INFO] number of examples: 986019
# [2020-03-26 14:31:13,452 INFO] Step 5400/100000; acc:  46.19; ppl: 13.82; xent: 2.63; lr: 0.00094; 2766/4084 tok/s;   7524 sec
# [2020-03-26 14:32:23,056 INFO] Step 5450/100000; acc:  45.14; ppl: 14.24; xent: 2.66; lr: 0.00095; 3933/5406 tok/s;   7594 sec
# [2020-03-26 14:33:31,650 INFO] Step 5500/100000; acc:  45.26; ppl: 14.32; xent: 2.66; lr: 0.00096; 3904/5401 tok/s;   7663 sec
# [2020-03-26 14:34:41,526 INFO] Step 5550/100000; acc:  46.75; ppl: 12.99; xent: 2.56; lr: 0.00097; 3862/5397 tok/s;   7732 sec
# [2020-03-26 14:35:48,837 INFO] Step 5600/100000; acc:  47.86; ppl: 12.29; xent: 2.51; lr: 0.00098; 3909/5443 tok/s;   7800 sec
# [2020-03-26 14:36:56,784 INFO] Step 5650/100000; acc:  47.48; ppl: 12.44; xent: 2.52; lr: 0.00099; 3935/5336 tok/s;   7868 sec
# [2020-03-26 14:38:05,393 INFO] Step 5700/100000; acc:  46.68; ppl: 12.97; xent: 2.56; lr: 0.00100; 3838/5404 tok/s;   7936 sec
# [2020-03-26 14:39:14,434 INFO] Step 5750/100000; acc:  47.33; ppl: 12.47; xent: 2.52; lr: 0.00100; 3899/5422 tok/s;   8005 sec
# [2020-03-26 14:40:21,446 INFO] Step 5800/100000; acc:  47.21; ppl: 12.69; xent: 2.54; lr: 0.00101; 3958/5325 tok/s;   8072 sec
# [2020-03-26 14:41:29,341 INFO] Step 5850/100000; acc:  47.13; ppl: 12.68; xent: 2.54; lr: 0.00102; 3989/5353 tok/s;   8140 sec
# [2020-03-26 14:42:37,194 INFO] Step 5900/100000; acc:  47.38; ppl: 12.28; xent: 2.51; lr: 0.00103; 4137/5363 tok/s;   8208 sec
# [2020-03-26 14:43:46,482 INFO] Step 5950/100000; acc:  45.43; ppl: 13.77; xent: 2.62; lr: 0.00104; 3910/5404 tok/s;   8277 sec
# [2020-03-26 14:44:55,094 INFO] Step 6000/100000; acc:  47.64; ppl: 11.86; xent: 2.47; lr: 0.00105; 4043/5370 tok/s;   8346 sec
# [2020-03-26 14:46:03,131 INFO] Step 6050/100000; acc:  47.28; ppl: 12.43; xent: 2.52; lr: 0.00106; 3942/5341 tok/s;   8414 sec
# [2020-03-26 14:47:11,591 INFO] Step 6100/100000; acc:  46.77; ppl: 12.88; xent: 2.56; lr: 0.00107; 3746/5438 tok/s;   8482 sec
# [2020-03-26 14:48:20,014 INFO] Step 6150/100000; acc:  47.79; ppl: 11.89; xent: 2.48; lr: 0.00107; 4052/5330 tok/s;   8551 sec
# [2020-03-26 14:49:29,642 INFO] Step 6200/100000; acc:  48.22; ppl: 11.55; xent: 2.45; lr: 0.00108; 3989/5420 tok/s;   8621 sec
# [2020-03-26 14:50:38,224 INFO] Step 6250/100000; acc:  46.31; ppl: 12.99; xent: 2.56; lr: 0.00109; 3828/5450 tok/s;   8689 sec
# [2020-03-26 14:51:46,300 INFO] Step 6300/100000; acc:  48.41; ppl: 11.47; xent: 2.44; lr: 0.00110; 4029/5392 tok/s;   8757 sec
# [2020-03-26 14:52:54,757 INFO] Step 6350/100000; acc:  47.47; ppl: 12.15; xent: 2.50; lr: 0.00111; 3901/5412 tok/s;   8826 sec
# [2020-03-26 14:54:02,118 INFO] Step 6400/100000; acc:  47.61; ppl: 12.16; xent: 2.50; lr: 0.00112; 3902/5354 tok/s;   8893 sec
# [2020-03-26 14:54:35,868 INFO] Loading dataset from nmt_subs_en_vi.train.1.pt
# [2020-03-26 14:54:35,888 INFO] number of examples: 3500
# [2020-03-26 14:54:43,666 INFO] Loading dataset from nmt_subs_en_vi.train.0.pt
# [2020-03-26 14:54:54,448 INFO] number of examples: 986019
# [2020-03-26 14:55:32,132 INFO] Step 6450/100000; acc:  48.65; ppl: 11.44; xent: 2.44; lr: 0.00113; 2824/4112 tok/s;   8983 sec
# [2020-03-26 14:56:40,508 INFO] Step 6500/100000; acc:  45.76; ppl: 13.40; xent: 2.60; lr: 0.00114; 3797/5415 tok/s;   9051 sec
# [2020-03-26 14:57:50,348 INFO] Step 6550/100000; acc:  46.67; ppl: 12.60; xent: 2.53; lr: 0.00114; 4000/5338 tok/s;   9121 sec
# [2020-03-26 14:58:59,605 INFO] Step 6600/100000; acc:  47.62; ppl: 11.98; xent: 2.48; lr: 0.00115; 3807/5435 tok/s;   9190 sec
# [2020-03-26 15:00:08,825 INFO] Step 6650/100000; acc:  48.65; ppl: 11.23; xent: 2.42; lr: 0.00116; 3796/5455 tok/s;   9260 sec
# [2020-03-26 15:01:15,335 INFO] Step 6700/100000; acc:  48.90; ppl: 11.14; xent: 2.41; lr: 0.00117; 4040/5320 tok/s;   9326 sec
# [2020-03-26 15:02:24,427 INFO] Step 6750/100000; acc:  48.43; ppl: 11.37; xent: 2.43; lr: 0.00118; 3876/5349 tok/s;   9395 sec
# [2020-03-26 15:03:33,040 INFO] Step 6800/100000; acc:  48.49; ppl: 11.33; xent: 2.43; lr: 0.00119; 3805/5468 tok/s;   9464 sec
# [2020-03-26 15:04:41,432 INFO] Step 6850/100000; acc:  48.09; ppl: 11.57; xent: 2.45; lr: 0.00120; 3847/5387 tok/s;   9532 sec
# [2020-03-26 15:05:48,462 INFO] Step 6900/100000; acc:  49.16; ppl: 10.81; xent: 2.38; lr: 0.00121; 4068/5364 tok/s;   9599 sec
# [2020-03-26 15:06:56,452 INFO] Step 6950/100000; acc:  47.96; ppl: 11.59; xent: 2.45; lr: 0.00121; 4091/5329 tok/s;   9667 sec
# [2020-03-26 15:08:05,148 INFO] Step 7000/100000; acc:  47.58; ppl: 11.78; xent: 2.47; lr: 0.00122; 3995/5389 tok/s;   9736 sec
# [2020-03-26 15:09:14,173 INFO] Step 7050/100000; acc:  47.60; ppl: 11.58; xent: 2.45; lr: 0.00123; 4017/5348 tok/s;   9805 sec
# [2020-03-26 15:10:21,863 INFO] Step 7100/100000; acc:  48.90; ppl: 10.80; xent: 2.38; lr: 0.00124; 4029/5360 tok/s;   9873 sec
# [2020-03-26 15:11:30,342 INFO] Step 7150/100000; acc:  48.27; ppl: 11.56; xent: 2.45; lr: 0.00125; 3688/5449 tok/s;   9941 sec
# [2020-03-26 15:12:39,188 INFO] Step 7200/100000; acc:  48.06; ppl: 11.34; xent: 2.43; lr: 0.00126; 4022/5330 tok/s;  10010 sec
# [2020-03-26 15:13:47,740 INFO] Step 7250/100000; acc:  49.01; ppl: 10.81; xent: 2.38; lr: 0.00127; 4030/5343 tok/s;  10079 sec
# [2020-03-26 15:14:57,717 INFO] Step 7300/100000; acc:  48.45; ppl: 11.11; xent: 2.41; lr: 0.00128; 3861/5455 tok/s;  10149 sec
# [2020-03-26 15:16:06,235 INFO] Step 7350/100000; acc:  48.76; ppl: 10.88; xent: 2.39; lr: 0.00128; 3950/5418 tok/s;  10217 sec
# [2020-03-26 15:17:14,063 INFO] Step 7400/100000; acc:  48.38; ppl: 11.18; xent: 2.41; lr: 0.00129; 3945/5379 tok/s;  10285 sec
# [2020-03-26 15:18:21,953 INFO] Step 7450/100000; acc:  49.61; ppl: 10.51; xent: 2.35; lr: 0.00130; 3944/5428 tok/s;  10353 sec
# [2020-03-26 15:19:24,008 INFO] Loading dataset from nmt_subs_en_vi.train.1.pt
# [2020-03-26 15:19:24,027 INFO] number of examples: 3500
# [2020-03-26 15:19:31,843 INFO] Step 7500/100000; acc:  49.92; ppl: 10.28; xent: 2.33; lr: 0.00131; 3620/5183 tok/s;  10423 sec
# [2020-03-26 15:19:31,853 INFO] Loading dataset from nmt_subs_en_vi.train.0.pt
# [2020-03-26 15:19:41,360 INFO] number of examples: 986019
# [2020-03-26 15:20:58,493 INFO] Step 7550/100000; acc:  46.79; ppl: 12.51; xent: 2.53; lr: 0.00132; 2921/4321 tok/s;  10509 sec
# [2020-03-26 15:22:08,490 INFO] Step 7600/100000; acc:  47.77; ppl: 11.40; xent: 2.43; lr: 0.00133; 4002/5379 tok/s;  10579 sec
# [2020-03-26 15:23:16,485 INFO] Step 7650/100000; acc:  48.05; ppl: 11.50; xent: 2.44; lr: 0.00134; 3849/5393 tok/s;  10647 sec
# [2020-03-26 15:24:26,475 INFO] Step 7700/100000; acc:  49.14; ppl: 10.59; xent: 2.36; lr: 0.00135; 3818/5446 tok/s;  10717 sec
# [2020-03-26 15:25:33,568 INFO] Step 7750/100000; acc:  50.43; ppl:  9.95; xent: 2.30; lr: 0.00135; 4007/5407 tok/s;  10784 sec
# [2020-03-26 15:26:41,900 INFO] Step 7800/100000; acc:  49.64; ppl: 10.39; xent: 2.34; lr: 0.00136; 3869/5370 tok/s;  10853 sec
# [2020-03-26 15:27:50,402 INFO] Step 7850/100000; acc:  48.76; ppl: 10.86; xent: 2.39; lr: 0.00137; 3864/5351 tok/s;  10921 sec
# [2020-03-26 15:28:59,488 INFO] Step 7900/100000; acc:  50.13; ppl: 10.02; xent: 2.30; lr: 0.00138; 3839/5450 tok/s;  10990 sec
# [2020-03-26 15:30:06,560 INFO] Step 7950/100000; acc:  49.20; ppl: 10.61; xent: 2.36; lr: 0.00139; 3989/5282 tok/s;  11057 sec
# [2020-03-26 15:31:14,611 INFO] Step 8000/100000; acc:  48.59; ppl: 10.97; xent: 2.39; lr: 0.00140; 3997/5378 tok/s;  11125 sec
# [2020-03-26 15:32:22,610 INFO] Step 8050/100000; acc:  49.30; ppl: 10.43; xent: 2.34; lr: 0.00139; 4112/5358 tok/s;  11193 sec
# [2020-03-26 15:33:31,836 INFO] Step 8100/100000; acc:  48.36; ppl: 10.99; xent: 2.40; lr: 0.00139; 3973/5386 tok/s;  11263 sec
# [2020-03-26 15:34:40,278 INFO] Step 8150/100000; acc:  49.47; ppl: 10.18; xent: 2.32; lr: 0.00138; 4001/5333 tok/s;  11331 sec
# [2020-03-26 15:35:48,772 INFO] Step 8200/100000; acc:  49.24; ppl: 10.46; xent: 2.35; lr: 0.00138; 3889/5369 tok/s;  11400 sec
# [2020-03-26 15:36:57,126 INFO] Step 8250/100000; acc:  48.68; ppl: 10.93; xent: 2.39; lr: 0.00138; 3764/5403 tok/s;  11468 sec
# [2020-03-26 15:38:05,913 INFO] Step 8300/100000; acc:  50.64; ppl:  9.59; xent: 2.26; lr: 0.00137; 4052/5352 tok/s;  11537 sec
# [2020-03-26 15:39:16,310 INFO] Step 8350/100000; acc:  49.35; ppl: 10.32; xent: 2.33; lr: 0.00137; 3929/5397 tok/s;  11607 sec
# [2020-03-26 15:40:24,504 INFO] Step 8400/100000; acc:  49.37; ppl: 10.32; xent: 2.33; lr: 0.00136; 3900/5400 tok/s;  11675 sec
# [2020-03-26 15:41:33,253 INFO] Step 8450/100000; acc:  50.15; ppl:  9.85; xent: 2.29; lr: 0.00136; 3975/5339 tok/s;  11744 sec
# [2020-03-26 15:42:41,710 INFO] Step 8500/100000; acc:  50.29; ppl:  9.87; xent: 2.29; lr: 0.00136; 3850/5449 tok/s;  11813 sec
# [2020-03-26 15:43:49,703 INFO] Step 8550/100000; acc:  49.38; ppl: 10.42; xent: 2.34; lr: 0.00135; 3851/5368 tok/s;  11881 sec
# [2020-03-26 15:44:13,502 INFO] Loading dataset from nmt_subs_en_vi.train.1.pt
# [2020-03-26 15:44:13,523 INFO] number of examples: 3500
# [2020-03-26 15:44:21,361 INFO] Loading dataset from nmt_subs_en_vi.train.0.pt
# [2020-03-26 15:44:32,740 INFO] number of examples: 986019
# [2020-03-26 15:45:20,642 INFO] Step 8600/100000; acc:  50.39; ppl:  9.89; xent: 2.29; lr: 0.00135; 2795/4056 tok/s;  11972 sec
# [2020-03-26 15:46:29,328 INFO] Step 8650/100000; acc:  48.53; ppl: 10.79; xent: 2.38; lr: 0.00134; 3889/5385 tok/s;  12040 sec
# [2020-03-26 15:47:38,779 INFO] Step 8700/100000; acc:  48.25; ppl: 11.04; xent: 2.40; lr: 0.00134; 3896/5369 tok/s;  12110 sec
# [2020-03-26 15:48:48,126 INFO] Step 8750/100000; acc:  50.67; ppl:  9.57; xent: 2.26; lr: 0.00134; 3827/5414 tok/s;  12179 sec
# [2020-03-26 15:49:56,476 INFO] Step 8800/100000; acc:  51.12; ppl:  9.32; xent: 2.23; lr: 0.00133; 3881/5428 tok/s;  12247 sec
# [2020-03-26 15:51:03,677 INFO] Step 8850/100000; acc:  51.34; ppl:  9.21; xent: 2.22; lr: 0.00133; 4001/5329 tok/s;  12315 sec
# [2020-03-26 15:52:12,905 INFO] Step 8900/100000; acc:  50.33; ppl:  9.65; xent: 2.27; lr: 0.00132; 3883/5323 tok/s;  12384 sec
# [2020-03-26 15:53:22,053 INFO] Step 8950/100000; acc:  50.43; ppl:  9.66; xent: 2.27; lr: 0.00132; 3807/5432 tok/s;  12453 sec
# [2020-03-26 15:54:30,657 INFO] Step 9000/100000; acc:  50.88; ppl:  9.45; xent: 2.25; lr: 0.00132; 3768/5380 tok/s;  12522 sec
# [2020-03-26 15:55:38,378 INFO] Step 9050/100000; acc:  51.22; ppl:  9.24; xent: 2.22; lr: 0.00131; 4030/5334 tok/s;  12589 sec
# [2020-03-26 15:56:46,757 INFO] Step 9100/100000; acc:  50.07; ppl:  9.79; xent: 2.28; lr: 0.00131; 4094/5303 tok/s;  12658 sec
# [2020-03-26 15:57:55,176 INFO] Step 9150/100000; acc:  49.86; ppl:  9.87; xent: 2.29; lr: 0.00131; 3992/5385 tok/s;  12726 sec
# [2020-03-26 15:59:04,271 INFO] Step 9200/100000; acc:  50.66; ppl:  9.28; xent: 2.23; lr: 0.00130; 4032/5349 tok/s;  12795 sec
# [2020-03-26 16:00:12,438 INFO] Step 9250/100000; acc:  50.60; ppl:  9.37; xent: 2.24; lr: 0.00130; 3952/5349 tok/s;  12863 sec
# [2020-03-26 16:01:20,807 INFO] Step 9300/100000; acc:  50.71; ppl:  9.56; xent: 2.26; lr: 0.00130; 3732/5429 tok/s;  12932 sec
# [2020-03-26 16:02:29,593 INFO] Step 9350/100000; acc:  51.18; ppl:  9.08; xent: 2.21; lr: 0.00129; 4058/5261 tok/s;  13000 sec

# %% [markdown]
# Теперь у нас есть модель-переводчик, исходный текст для перевода и их референсный перевод от Amazon. Для примера выведем 10 лучших переводов одного предложения (автоматическое определение правильного числа переводов для каждого предложения -- потом)

# %%
# !onmt_translate -model transformer_step_35000.pt -src ../../../duolingo/data/en_pt/train/train_duolingo_en.txt \
-output train_duolingo_pred10_pt.txt -n_best 10 -replace_unk
# Out:
# [2020-03-30 21:45:26,228 INFO] Translating shard 0.
# PRED AVG SCORE: -0.2945, PRED PPL: 1.3425

# %%
# !head -n 20 train_duolingo_pred10_pt.txt
# Out:
# Você poderia baixar o video para mim?
# Você poderia video o video para mim?
# Você poderia video o video
# Você poderia baixar esse video para mim?
# poderia baixar o video para mim?
# Você poderia baixar o video para mim.
# Você poderia baixar o video para mim? - Não.
# Você poderia baixar o video para mim? - Sim.
# Você poderia baixar o video para mim? - Não, obrigado.
# Você poderia baixar o video para mim? - Sim!
# a livraria não é nesta rua.
# A livraria não é nesta rua.
# a livraria não está nesta rua.
# A livraria não está nesta rua.
# a livraria não é desta rua.
# a livraria.
# a livraria não é nesta rua.
# a livraria não é nesta rua.
# a livraria não é nesta rua.
# a livraria não é nesta rua.

# %%
# !onmt_translate -model transformer_step_35000.pt -src ../../../duolingo/data/en_pt/train/train_duolingo_en.txt \
-output train_duolingo_pred_pt.txt -replace_unk
# Out:
# [2020-03-30 22:30:47,677 INFO] Translating shard 0.
# PRED AVG SCORE: -0.2945, PRED PPL: 1.3425

# %% [markdown]
# ## TODO: Evaluation

# %%
# !pwd
# Out:
# /content/gdrive/My Drive/data/work/Panchenko/language_models/en_pt/openNMT

# %%
from nltk.translate.bleu_score import corpus_bleu, sentence_bleu
import re

references = []
predictions = []
with open('../../../duolingo/data/en_pt/train/train_duolingo_pt.txt') as gold:
    for sentence in gold.readlines():
        s = ' '.join(re.split(r'([^0-9a-zÀ-ÿ\s])',sentence.lower()))
        s = re.sub(r' +', ' ', s)
        references.append(s.split())
with open('train_duolingo_pred_pt.txt') as preds:
    for sentence in preds.readlines():
        s = ' '.join(re.split(r'([^0-9a-zÀ-ÿ\s])',sentence.lower()))
        s = re.sub(r' +', ' ', s)
        predictions.append(s.split())
print(predictions[1])
print(references[1])
# Out:
# ['a', 'livraria', 'não', 'é', 'nesta', 'rua', '.']
# ['a', 'livraria', 'não', 'é', 'nesta', 'rua', '.']

# %%
corpus_bleu(references, predictions)
# Out:
# /usr/local/lib/python3.6/dist-packages/nltk/translate/bleu_score.py:490: UserWarning:
# Corpus/Sentence contains 0 counts of 2-gram overlaps.
# BLEU scores might be undesirable; use SmoothingFunction().
#   warnings.warn(_msg)
# 0.6922290349478658

# %%
os.chdir(os.path.join(path_to_duolingo, 'train'))
hypothesises = []
with open('train.en_pt.gold.txt') as f:
    for sentence in f.readlines():
        if sentence.startswith('prompt_'):
            obnulyay = True
            continue
        else:
            sentence = sentence.split('|')[0]
            s = ' '.join(re.split(r'([^0-9a-zÀ-ÿ\s])',sentence.lower()))
            s = re.sub(r' +', ' ', s)
            if obnulyay:            
                hypothesises.append([s.split()])
                obnulyay = False
            else:
                hypothesises[-1].append(s.split())
# Out:
# ['podes', 'baixar', 'aquele', 'vídeo', 'pra', 'mim', '?']

# %%
print(corpus_bleu(hypothesises, references))
# Out:
# 0.9527666953628904

# %%
beam_predictions = []
with open(os.path.join(path_to_model+'/openNMT/train_duolingo_pred10_pt.txt')) as preds:
    for i, sentence in enumerate(preds.readlines()):
        if i%10==0:
            continue
        s = ' '.join(re.split(r'([^0-9a-zÀ-ÿ\s])',sentence.lower()))
        s = re.sub(r' +', ' ', s)
        if i%10==1:
            beam_predictions.append([s.split()])
        else:
            beam_predictions[-1].append(s.split())

print(corpus_bleu(beam_predictions, references))
# Out:
# 0.8845647500357965

# %%
for i in range(len(beam_predictions[2])):
    print(sentence_bleu([predictions[2]], beam_predictions[2][i]))
# Out:
# 0.6042750794713536
# 0.7037259479962376
# 0.6042750794713536
# 0.5506953149031837
# 0.5169731539571706
# 0.392814650900513
# 0.392814650900513
# 0.392814650900513
# 0.3508439695638686
# /usr/local/lib/python3.6/dist-packages/nltk/translate/bleu_score.py:490: UserWarning:
# Corpus/Sentence contains 0 counts of 4-gram overlaps.
# BLEU scores might be undesirable; use SmoothingFunction().
#   warnings.warn(_msg)
# /usr/local/lib/python3.6/dist-packages/nltk/translate/bleu_score.py:490: UserWarning:
# Corpus/Sentence contains 0 counts of 3-gram overlaps.
# BLEU scores might be undesirable; use SmoothingFunction().
#   warnings.warn(_msg)

# %% [markdown]
# Проверив это на ещё нескольких наборах предложений, я эмпирически пришёл к выводу, что предложения, у которых по отношению к лучшему переводу BLEU-score меньше 0.5, не являются качественным переводом исходного предложения.

# %%
for i in range(len(beam_predictions[2])):
    print(*beam_predictions[2][i])
# Out:
# posso caminhar até lá ?
# posso andar lá ?
# posso ir até lá ?
# posso caminhar lá ?
# posso andar até lá ? - não .
# posso caminhar até lá ? - não .
# posso caminhar até lá ? - não !
# posso andar até lá ? - não , obrigado .
# posso andar até lá ? - não , não posso .

# %% [markdown]
# # Парафраз

# %% [markdown]
# Для парафраза нужна языковая модель таргетного языка. Первый вопрос который у меня возникает, нормально ли учить языковую модель не такую же как у переводчика. Сходу кажется, что нет. Далее вопрос, насколько легко достать из переводчика языковую модель его таргетного языка. Я потратил несколько часов, но так и не смог получить доступ к модели нашего openNMT трансформера.
# Значит нам нужно создавать свою модель, в которой будет реализован и перевод трансформером и функционал для парафраза(((
#
# Либо безумная идея: дообучить трансформер переводить предложения в последовательности предложений, обучая на паре английский-96португальских. А потом эти предложения сплитать и засовывать в предикт.

# %% [markdown]
# # Коммит в соревнование

# %%
os.chdir('/content/gdrive/My Drive/data/work/Panchenko/language_models/en_pt/openNMT')
# !onmt_translate -model transformer_step_35000.pt -src ../../../duolingo/data/en_pt/dev/dev_duolingo_en.txt \
-output ../../../duolingo/data/en_pt/dev/weak_predictions.txt -replace_unk --ignore_when_blocking 3 -n_best 10
# Out:
# [2020-03-31 01:04:40,826 INFO] Translating shard 0.
# PRED AVG SCORE: -0.4697, PRED PPL: 1.5995

# %%
# !head -n 30 '../../../duolingo/data/en_pt/dev/weak_predictions.txt'
# Out:
# O que disse o patrão?
# Bem, o que o chefe disse?
# Bem, o que disse o chefe?
# Bem, o que é que o chefe disse?
# Bem, o que disse o patrão?
# Bem, o que é que o patrão disse?
# Bem, o que é que o chefe respondeu?
# Bem, o que é que o chefe disseste?
# Bem, o que é que o chefe disse
# Bem, o que é que o chefe disse?
# São cinquenta fifty por pessoas sem o person
# É 50 fifty por pessoa sem o person
# É 50 fifty por pessoa sem a person
# É 50 xelins por pessoa sem o person
# É 50 xelins por pessoa sem a person
# São cinquenta fifty por pessoas sem o person
# São cinquenta fifty por pessoas sem o person
# São cinquenta fifty por pessoas sem o person
# São cinquenta fifty por pessoas sem o person
# São cinquenta fifty por pessoas sem o person
# Já tens filhos?
# Você já tem filhos?
# Já tem filhos?
# Já têm filhos?
# Tu já tens filhos?
# Você já tem filhos? do
# Você já tem filhos? - Eu sei.
# Você já tem filhos? _BAR_
# Você já tem filhos? - Sim!
# Você já tem filhos? - Sim.

# %%
import numpy as np
prompts = open(path_to_duolingo+'/dev/dev.'+course+'.prompts.txt').readlines()
preds = open(path_to_duolingo+'/dev/weak_predictions.txt').readlines()
with open(path_to_duolingo+ '/dev/preds.txt', 'w') as final:
    for j in range(len(prompts)):
        final.writelines(prompts[j])
        translations = []
        for i in range(10):
            s = preds[j*10+i].strip()
            s = ' '.join(re.split(r'([^0-9a-zÀ-ÿ\s])',s.lower()))
            s = re.sub(r' +', ' ', s)
            translations.append(s)
        translations = np.unique(translations)
        final.writelines(translations[0]+'\n')
        for i in range(1, len(translations)):
            if sentence_bleu([translations[0]], translations[i]) >= 0.5:
                final.writelines(translations[i]+'\n')
        final.writelines('\n')
# Out:
# /usr/local/lib/python3.6/dist-packages/nltk/translate/bleu_score.py:490: UserWarning:
# Corpus/Sentence contains 0 counts of 2-gram overlaps.
# BLEU scores might be undesirable; use SmoothingFunction().
#   warnings.warn(_msg)
# /usr/local/lib/python3.6/dist-packages/nltk/translate/bleu_score.py:490: UserWarning:
# Corpus/Sentence contains 0 counts of 4-gram overlaps.
# BLEU scores might be undesirable; use SmoothingFunction().
#   warnings.warn(_msg)
# /usr/local/lib/python3.6/dist-packages/nltk/translate/bleu_score.py:490: UserWarning:
# Corpus/Sentence contains 0 counts of 3-gram overlaps.
# BLEU scores might be undesirable; use SmoothingFunction().
#   warnings.warn(_msg)

# %%
# !cat '/content/gdrive/My Drive/data/work/Panchenko/duolingo/data/en_pt/dev/preds.txt'
# Out:
# prompt_15049b3b99054c230685063e328369a4|well, what did the boss say?
# bem , o que disse o chefe ?
# bem , o que disse o patrão ?
# bem , o que o chefe disse ?
# bem , o que é que o chefe disse
# bem , o que é que o chefe disse ?
# bem , o que é que o chefe disseste ?
# bem , o que é que o chefe respondeu ?
# bem , o que é que o patrão disse ?
# o que disse o patrão ?
#
# prompt_aacb068d672931817ffd01ea6b0e0609|it's fifty euros per person without the discount.
# são cinquenta fifty por pessoas sem o person
# é 50 fifty por pessoa sem a person
# é 50 fifty por pessoa sem o person
# é 50 xelins por pessoa sem o person
#
# prompt_68125d9e6cf2f7d6e3b247b33d53bf8b|do you have children already?
# já tem filhos ?
# já tens filhos ?
# já têm filhos ?
# tu já tens filhos ?
# você já tem filhos ?
# você já tem filhos ? - sim !
# você já tem filhos ? - sim .
# você já tem filhos ? _ bar _
# você já tem filhos ? do
#
# prompt_9ddb373f4c02ec24608d7789d73618a5|i must go out.
# devo sair .
# preciso sair .
# tenho de sair .
#
# prompt_33e043560085db61736153782732d04c|are you kicking the table?
# estás a dar - lhe a mesa ?
# estás a dar a volta à mesa .
# estás a dar a volta à mesa ?
# estás a dar a volta à mesa e a mesa .
# estás a dar a volta à mesa e table ?
# estás a dar uma volta ?
# estás a dar uma volta à mesa .
# estás a dar uma volta à mesa ?
# estás a table ? a mesa ?
#
# prompt_623d076b6912033bcf26a79a6af3c0ff|i would like a cake, please.
# eu gostaria de um bolo , por favor !
# eu gostaria de um bolo , por favor .
# eu gostaria de um bolo , por favor . - a
# eu gostaria de um bolo , por favor . - obrigado .
# eu gostaria de um bolo , por favor . a
# eu gostaria de um bolo , por favor ?
# gostaria de um bolo , por favor .
# gostava de um bolo , por favor .
# queria um bolo , por favor .
# quero um bolo , por favor .
#
# prompt_c69d0fa7d83083c1baa22487b0bff37b|where is the best place to park at the hotel?
# onde fica o melhor lugar do hotel ?
# onde fica o melhor lugar para estacionar no hotel ?
# onde fica o melhor lugar para estacionar no hotel ? - não sei .
# onde fica o melhor sítio para estacionar no hotel ?
# onde é o melhor lugar para estacionar no hotel ?
# onde é que fica o melhor lugar do hotel ?
#
# prompt_f1004884c3ce2ea1c2716707406eedd3|you can wait here.
#  - pode esperar aqui .
#  - pode esperar aqui . - claro .
#  - pode esperar aqui . - está bem .
#  - pode esperar aqui . - o quê ?
#  - pode esperar aqui . - sim , senhor .
#  - pode esperar aqui . - sim .
# pode esperar aqui .
# pode esperar por aqui .
# podes esperar aqui .
# você pode esperar aqui .
#
# prompt_0887b6567ccb76674f594e920a066c0a|is she at home?
#  - ela está em casa ?
#  - ela está em casa ? - não .
#  - ela está em casa ? - sim , senhor .
#  - ela está em casa ? - sim .
# ela está em casa ?
# ela está em casa ? - não .
# ela está em casa ? - sim .
# ela está lá em casa ?
# está em casa ?
#
# prompt_8d7bde6f5ecf1241ce6c770c2a62e018|where are they going now?
# aonde vão agora ?
# onde vão agora ?
# para onde vão agora ?
#
# prompt_3aa550883ba189fd38ab7cd99a2c1da5|as you wish!
# não mintas .
# que wish !
#
# prompt_d5941d9082dbce0e38b1c6b89bcca216|which flight is less expensive?
# qual barco é menos caro ?
# qual voo é menos cara ?
# qual voo é menos caro ?
# qual vôo é menos cara ?
# qual vôo é menos caro ?
#
# prompt_e8102687e3d9697cb7a1686e2717d6e0|she cannot believe it.
# ela não pode acreditar .
# ela não pode acreditar nisso .
# ela não pode acreditar nisso . she
# ela não pode acreditar nisto .
# ela não pode crer .
# não pode acreditar .
#
# prompt_0618629fa31291c3a239bc75b7ef6c05|don't forget to give back my skates!
# não se esqueça de devolver o meu skates !
# não se esqueçam de devolver o meu skates !
# não te esqueças de devolver a skates !
# não te esqueças de devolver o meu my
# não te esqueças de devolver o meu my don ' t
# não te esqueças de devolver o meu my don ' t de volta .
# não te esqueças de devolver o meu my don ' t don ' t
# não te esqueças de devolver o meu my don ' t e não me skates !
# não te esqueças de me devolver o skates !
#
# prompt_12885b75eeeb12e8e968d215ecd5856b|good luck at work.
# boa sorte .
#
# prompt_0a86c80c414e6d7d9faad2494d32f9ca|our class read those books last month.
#  - a nossa aula leu os livros no mês passado .
# a nossa aula leu os livros no mês passado .
# a nossa aula leu os livros no mês passado . - a nossa classe vi uma class
# a nossa aula leu os livros no mês passado . - esta é a minha classe .
# a nossa aula leu os livros no mês passado . - esta é a mãe .
# a nossa aula leu os livros no mês passado . - esta é a nossa classe .
# a nossa aula leu os livros no mês passado . _ bar _
# nossa aula leu aqueles livros no mês passado .
# nossa aula leu esses livros no mês passado .
# nossa aula leu os livros no mês passado .
#
# prompt_bfe3d845b1c1336a7f5c0431517ad879|can we go to the bookstore?
# podemos ir ao to
# podemos ir para a to
# podemos ir para o the
# podemos ir à to
#
# prompt_2f84d45a9fbb5ae2a28ea5afa434f3f7|he takes a private route.
# ele leva uma estrada privada .
# ele toma uma estrada particular .
# ele toma uma estrada privada .
#
# prompt_10fac10864fce98aed2d79e4eca0853b|in ireland, it's useful to carry an umbrella.
# em umbrella . é útil levar um chapéu de chuva .
# em umbrella . é útil levar um chapéu de chuva de chuva .
# em umbrella . é útil levar um chapéu de chuva de chuva ou mês .
# em umbrella . é útil levar um chapéu de chuva de guarda - chuva .
# em umbrella . é útil levar um guarda - chuva .
# em umbrella . é útil ter um chapéu de chuva .
# em umbrella . é útil ter um chapéu de chuva de chuva .
# em umbrella . é útil ter um chapéu de chuva de guarda - chuva .
# em umbrella . é útil ter um guarda - chuva .
# em umbrella . é útil tomar um chapéu de chuva .
#
# prompt_6ae20adf024f6de0abce414cf3d8f2c4|the check, please.
# a conta , por favor .
# o check , por favor .
# o cheque , por favor .
#
# prompt_8ed47e5f9a627f693a35a2bbcc3f1324|what size are these shorts?
# de que tamanho são essas size
# de que tamanho são essas size !
# de que tamanho são essas size - shorts ?
# de que tamanho são essas size - são shorts ?
# de que tamanho são essas size de shorts ?
# de que tamanho são essas size these
# que tamanho são essas these
# que tamanho são estas these
# que tamanho são estes these
#
# prompt_966e49edd054bedaf63ce569dc92ba3e|he is preparing for a concert.
# ele está a preparar um concert .
# ele está a preparar um concerto .
# ele está preparando um concerto .
# ele está se preparando para um concert .
# ele está se preparando para um concerto .
# ele está se preparando para um concerto de concert .
# está a preparar um concerto .
# preparing para um concerto .
#
# prompt_1604325b889c7d18faab2c45961ca5ea|are they sitting together?
# eles estao sentados juntos ?
# eles estão sentados juntos ?
# eles estão sentados juntos ? - claro .
# eles estão sentados juntos ? - não .
# eles estão sentados juntos ? - sim .
# eles estão sentados juntos ? - sim senhor .
# estão sentados juntos ?
#
# prompt_45dca8aeac809f6923fe8c68c747a37c|i'm checking my email.
# estou a verificar a email .
# estou a verificar as email .
# estou a verificar as minhas email .
# estou a verificar as minhas email . - está bem .
# estou a verificar as minhas email . checking
# estou a verificar as minhas malas .
# estou a verificar o meu email .
#
# prompt_dfbe47f6c1179023b736e36ab942a2cc|did you find anything on the web?
# encontraste algo no find
# encontraste algo nos anything
# encontraste alguma coisa na find
# encontraste alguma coisa no find
# encontraste alguma coisa no find - não .
# encontrou alguma coisa no find
#
# prompt_bc883f0b8aa3f1973b81438729144f9c|lorena likes to listen to the violin.
# antonio gosta de ouvir esse violino .
# antonio gosta de ouvir o violino .
# antonio gosta de ouvir o violino . -
# antonio gosta de ouvir o violino . - eu também .
# antonio gosta de ouvir o violino . - não
# antonio gosta de ouvir o violino . - the
# antonio gosta de ouvir o violino . lorena
# antonio gosta de ouvir violino .
# hector gosta de ouvir o violino .
# hector gosta de ouvir violino .
#
# prompt_f85e0d8b9873324cc49da72097a3bdad|you sign your name.
# assina o teu nome .
# assine o seu nome .
# sign o seu nome .
# sign seu nome .
# você assina o seu nome .
# você assina o seu nome . - you
# você assina o seu nome . . .
# você assina o seu nome . you
#
# prompt_43f05881d2a670aea5410ad1173e07c5|try to find out if everything he said is true.
# tenta descobrir se tudo o que disse é verdade .
# tenta descobrir se tudo o que ele disse é verdade .
# tenta descobrir se tudo o que ele disse é verdade . - não ?
# tenta descobrir se tudo o que ele disse é verdade . - to
# tenta descobrir se tudo o que ele disse é verdade . if
# tente descobrir se tudo o que disse era verdade .
# tente descobrir se tudo o que disse é verdade .
# tente descobrir se tudo o que ele disse é verdade .
# tente descobrir se tudo o que ele disse é verdade . - não ?
# tente descobrir se tudo o que ele disse é verdade . - o quê ?
#
# prompt_611e304b074527cba4e1e19d6b579892|they're taking the bus today.
# eles estão tomando o autocarro hoje .
# eles vão apanhar o autocarro hoje .
# eles vão apanhar o autocarro hoje . - já sei .
# eles vão tomar o autocarro hoje .
# estão a apanhar o autocarro hoje .
# vão apanhar o autocarro hoje .
#
# prompt_5b868c5e6f2ce094a1fdb921f55c6bde|it is nothing serious.
# não é nada de grave .
# não é nada de grave . - não .
# não é nada de grave . - por que não ?
# não é nada de grave . nothing
# não é nada de grave . não é nada .
# não é nada de grave . não é nada sério .
# não é nada grave .
# não é nada sério .
#
# prompt_be68067dbf2195a27c6472c519a4f97e|very busy.
#  - muito ocupado .
#  - muito ocupado . - muito melhor .
# muito ocupada .
# muito ocupado .
# muito que fazer . - muito ocupado .
#
# prompt_4dd87390253fb1dbfe3d2280d6db756b|let's go to the zoo.
# vamos ao jardim zoológico .
# vamos ao jardim zoológico . - porquê ?
# vamos ao zoológico .
# vamos para o zoológico .
# vamos para o zoológico . - porquê ?
# vamos para o zoológico . _ bar _
#
# prompt_548f1110d6a1f1687b0828b95cf75d0a|it has a small and rich economy.
# tem um pequeno e rico rich
# tem uma pequena e rica and
#
# prompt_aff01cc40396f137b3d396b53ec6f7f8|we're eating cake now.
# agora comemos bolo .
# agora vamos comer bolo .
# estamos comendo bolo .
# vamos comer bolo .
# vamos comer bolo agora .
#
# prompt_905cfa886ce1f375647b3580f5680db1|what should you do when you have an accident?
# o que deve fazer quando teve um acidente ?
# o que deve fazer quando você teve um acidente ?
# o que faria quando teve um acidente ?
# o que faria se tivesse um acidente ?
#
# prompt_e629536c983175c053303e335f663dfa|she's recorded that song twice.
# ela recorded a canção duas vezes .
# ela recorded duas vezes .
# ela recorded duas vezes a tua história .
# ela recorded duas vezes a tua história . that
# ela recorded duas vezes essa canção
# ela recorded duas vezes essa canção .
# ela recorded essa canção duas vezes .
#
# prompt_f46a2bc88e7714c07b19fba5871eab3f|we wear boots on cold days.
# usamos botas em dias cold
# usamos botas em dias de frio .
# usamos botas em dias de frio . - sim .
# usamos botas em dias de frio . on
# usamos botas em dias frios .
# usamos botas em tempos cold
# usamos botas nos dias de frio .
#
# prompt_9c132f28e4ad883602ea532764de5608|can you be my driver today?
# pode ser o meu cocheiro hoje ?
# pode ser o meu condutor hoje ?
# pode ser o meu motorista , hoje ?
# pode ser o meu motorista hoje ?
# pode ser o meu taxista hoje ?
#
# prompt_3f82d654b86d633f1ae7f5f823155341|i've always been interested in fashion.
# sempre me interessou a moda .
# sempre me interessou ao moda .
# sempre me interessou de moda .
# sempre me interested com moda .
# sempre me interested em moda .
#
# prompt_b05897e075db3bceb1732f63d29aa462|don't put on too much makeup.
# não coloque muita makeup .
# não coloque muita makeup . em demasia .
# não coloque muita makeup . em mais .
# não coloque muita makeup . em mais makeup .
# não coloque muita makeup . em mais maquilhagem .
# não coloque muita makeup . em makeup .
# não coloque muita maquilhagem .
# não makeup . muita maquilhagem .
# não makeup . muito .
#
# prompt_70a6e252b38ffbf67126d72c3ffad2e3|she never takes medicine.
# ela nunca aceita medicina .
# ela nunca tira medicina .
# ela nunca toma medicina .
# ela nunca toma medicine .
#
# prompt_1ba2f4af35180832821542412758a439|i have to open everything.
# eu tenho de abrir tudo .
# eu tenho de abrir tudo . - não .
# eu tenho que abrir tudo !
# eu tenho que abrir tudo .
# eu tenho que abrir tudo . - e você ?
# eu tenho que abrir tudo . - não .
# preciso abrir tudo .
# tenho de abrir tudo .
# tenho que abrir tudo .
#
# prompt_e4c3805986ada98ce60248b38593da8b|joseph lives in new york.
# a new vive em novos lives
# new vive em novos lives
# o new vive em new
# o new vive em novos lives
# o new vive em novos portos
# o new vive em novos portos de york .
# o new vive em novos portos joseph
#
# prompt_53cf1cf1351d32408673f8729dc6ac2d|it's almost eleven o'clock.
# são quase 11 horas .
# são quase onze horas !
# são quase onze horas .
# é quase onze horas .
#
# prompt_259aae8395fd04bb236bba003f38baac|the lawyer works on this floor.
# o advogado trabalha nesta palavra .
# o advogado trabalha neste andar .
# o advogado trabalha neste chão .
# o advogado trabalha neste piso .
#
# prompt_37884bdbb17394d57afe4a586f9976ba|somebody asked us to be quiet.
# alguém nos pediu para ficar calado .
# alguém nos pediu para ficar quieto .
# alguém nos pediu para nos quiet .
# alguém nos pediu para nos quiet . calado .
# alguém nos pediu para nos quiet . em marcha .
# alguém nos pediu para nos quiet . em paz .
# alguém nos pediu para nos quiet . em silêncio .
# alguém nos pediu para quiet .
#
# prompt_f1baf9714f423fb6b772a0cbe6dfbcbd|does she write for a magazine?
# ela escreve para uma revista de magazine ?
# ela escreve para uma revista de moda ?
# ela escreve por uma caixa de magazine ?
# ela escreve por uma magazine ?
# ela escreve por uma revista de magazine ?
# ela escreve por uma revista de moda ?
# ela escreve por umas magazine ?
#
# prompt_56e443275609c3b2092eae268d7735ae|the white sofa is soft, but the other is hard.
# o sofá branco é soft , mas a outra é difícil .
# o sofá branco é soft , mas o outro é duro .
# o sofá branco é soft , mas o outro é duro . -
# o sofá branco é soft , mas o outro é duro . - estou bem .
# o sofá branco é soft , mas o outro é duro . - hard .
# o sofá branco é soft , mas o outro é duro . - o que the
# o sofá branco é soft , mas o outro é duro . the
# o sofá é white mas a outra é difícil .
#
# prompt_3f3fbb605b0d68f72f8e756b5805c623|when it's hot, you should drink a lot of water.
# quando estiver quente , devias beber muita água .
# quando está quente , devias beber muita água .
# quando está quente , devias beber muito água .
# quando está quente , tens de beber muita água .
# quando está quente , tens de beber muita água . - a sério .
# quando está quente , tens de beber muita água . - para a cama .
# quando está quente , tens de beber muita água . - para a água .
# quando está quente , tens de beber muita água . _ bar _
# quando está quente , tens de beber muita água . when
#
# prompt_e99c004c2bfb89d2a4bb5a7b05ce7910|golf players must practice hitting the ball.
# os jogadores de golf têm de praticar a bola
# os jogadores de golf têm de praticar a bola .
# os jogadores de golf têm de praticar a bola de golfe .
# os jogadores têm de praticar golf ao ball .
# os jogadores têm de praticar golfe a golf
#
# prompt_8d083e0b2b005206dea65e32521cad7f|they have changed the password.
# eles mudaram a senha .
# eles mudou a senha .
# eles password . a senha .
# eles tocaram a senha .
# eles tomaram a senha .
#
# prompt_78216ead7275c5afbabdf792513e5261|what's your last name?
#  - qual é o seu apelido ?
# qual é o seu apelido ?
# qual é o seu nome ?
# qual é o seu último nome ?
#
# prompt_69219ea84d5805d8f58e20161b228d8f|how do they say their names?
#  - como se chamam ?
# como se chamam ?
# como é que se chamam ?
#
# prompt_2c1dce7c8bbe8b61e4f15165638807d8|it is like starting again.
# starting
#
# prompt_785cc85928f3e56111a7335c4ac2a96e|we will not make money with that.
# não vamos ganhar dinheiro .
# não vamos ganhar dinheiro com isso .
# não vamos ganhar dinheiro com isso . - não ?
# não vamos ganhar dinheiro com isso . - nós não money
# não vamos ganhar dinheiro com isso . - o que é ?
# não vamos ganhar dinheiro com isso . - o quê ?
# não vamos ganhar dinheiro com isto .
# não vamos ganhar nada com isso .
# nós não vamos ganhar dinheiro .
#
# prompt_89bce4ad2ebc22fca6e404449fb402a0|it's warm here in the spring.
# está calor aqui na primavera .
# está quente , na primavera .
# está quente aqui na primavera .
# está quente aqui na primavera . - primavera .
# está quente aqui na primavera . - sim ?
# faz calor aqui na primavera .
#
# prompt_abb8042e0c97662fdf3792834b655e86|i have a terrible toothache.
# eu tenho um grande terrible
# eu tenho um grande terrible - eu também .
# eu tenho um grande terrible - eu tenho .
# eu tenho um grande terrible - que toothache .
# eu tenho um grande terrible - sim , senhor .
# eu tenho um grande terrible toothache .
# eu tenho um terrível terrible
# eu tenho uma terrível terrible
# tenho um terrível terrible
# tenho uma terrível terrible
#
# prompt_3cc5863c5254518c8905539cb9d402af|they have followed me all day.
# eles me followed o dia todo .
# eles me followed o dia todo . - eles estão todos eles .
# eles me followed o dia todo . - está tudo bem .
# eles me followed o dia todo . all
# eles me o dia todo .
# eles me seguir o dia todo .
# eles me todo o dia .
#
# prompt_5b8d8cd961c151468dd0e85b53561e05|angela thinks the square, silver mirror is cool.
# o espelho thinks espelho está fresco .
# o espelho thinks espelho está frio .
#
# prompt_436bf9fde6cb6150548a00cf9a078298|i have six professors.
# eu tenho seis pacotes .
# eu tenho seis professors .
# tenho seis pacotes .
# tenho seis professors .
#
# prompt_174e2e1ad6271dfdee0415518e64476d|are they having lunch downtown today?
# eles vão almoçar na baixa , hoje ?
# eles vão almoçar na baixa , hoje ? - claro que sim .
# eles vão almoçar na baixa , hoje ? - não , obrigado .
# eles vão almoçar na baixa , hoje ? - não .
# eles vão almoçar na baixa , hoje ? - não posso .
# eles vão almoçar na baixa , hoje ? - sim .
# eles vão almoçar na cidade hoje ?
# eles vão comer na cidade hoje ?
# vão almoçar na baixa , hoje ?
#
# prompt_2f20025a267aa1925e4a003d654542b4|the ducks had a meeting with the chickens.
# os patos tinham uma reunião com as galinhas .
# os patos tinham uma reunião com os galinhas .
# os patos tiveram uma reunião com os galinhas .
#
# prompt_659bc3ca522b5e6aea8cf59a4f2dfa23|he bought her a ring.
# comprou um anel .
# ele comprou um anel .
# ele comprou um anel . - não sei .
# ele comprou um anel . he
#
# prompt_9ec430dde8a01b93562d202f21d74edd|the fried mushrooms are fantastic!
# os cogumelos .
# os cogumelos . os mushrooms
#
# prompt_b2648b3db1e27d5d40b9e97cfaf73db6|the steak is served with a salad.
# o bife é servido com uma salada .
# o bife é servido com uma salada . - dá - lhe um bife ,
# o bife é servido com uma salada . - quanto é ?
# o bife é servido com uma salada . - um gelo .
# o bife é servido com uma salada . _ bar _
# o bife é servido com uma salada . a
# o bife é servido numa salada .
# o bife é servido para uma salada .
# o bife é servido uma salada .
#
# prompt_88d15091cfae16baad00d32ad03ff6b9|they go out every friday.
# eles saem todas as friday .
# eles saem todas as friday . - friday .
# eles saem todas as friday . - não posso .
# eles saem todas as friday . - sim , senhor .
# eles saem todas as friday . - sim .
# eles saem todas as friday . every
# eles saem todas friday .
# eles vão todas as friday .
# saem todas as friday .
#
# prompt_4e49bc51eff008910317c47fcc86e530|he plays baseball very well.
# ele joga muito bem em basebol .
# ele joga muito bem em beisebol .
# ele toca muito bem a beisebol .
# ele toca muito bem ao beisebol .
# ele toca muito bem ao beisebol . - sim .
#
# prompt_4a779ccb7c19ad55074272f80b7ad0ac|it's too hot!
# está demasiado quente !
# está muito quente !
# isto está muito quente !
# isto está muito quente ! !
#
# prompt_0c9a89d0788d2d60349f4c8bfe452caa|she always eats a sandwich for lunch.
# ela come sempre um sanduíche para almoçar .
# ela come sempre um sanduíche para o almoço .
# ela come sempre um sanduíche para o almoço . - ela come uma sandwich
# ela come sempre um sanduíche para o almoço . - obrigado .
# ela come sempre um sanduíche para o almoço . - oh , não !
# ela come sempre um sanduíche para o almoço ?
# ela come sempre um sandwich para o almoço .
# ela sempre come uma sandwich para o almoço .
#
# prompt_1d697316f83c68218de16fba53c0dafc|excuse me, are you mrs. brown?
# desculpe , é a mrs . mrs .
# desculpe , é a sra . mrs .
# desculpe , é a sra . mrs . - não .
# desculpe , é a sra . mrs . - sim .
# desculpe , é a sra . mrs . brown ?
# desculpe , é mrs . excuse
# desculpe - me , é a sra . mrs .
# desculpe - me , é mrs . mrs .
#
# prompt_9be60701e3084d1b3b7bbbb43d1fd75e|i have a bag.
# eu tenho um pacote .
# eu tenho um saco .
# eu tenho uma mala .
# tenho um saco .
#
# prompt_a43fdd66a2b2961d8841a8bbd5acfd8e|he is neither a teacher nor a lawyer.
# ele não é nem professora nem advogado .
# ele não é nem um advogado nem advogado .
# ele não é nem um advogado nem um advogado
# ele não é nem um advogado nem um advogado !
# ele não é nem um advogado nem um advogado .
# ele não é nem um advogado nem um advogado ?
# ele não é nem um advogado nem um advogado deles .
# ele não é professor nem advogado .
# ele não é professor nem um advogado .
# ele não é um professor nem advogado .
#
# prompt_c9a6158f5b7f78c3025e0770b9abe50d|i'm not wearing a jacket.
# não estou a usar casaco .
# não estou a usar um casaco .
# não estou a usar um jacket .
# não estou usando casaco .
# não estou usando um casaco .
#
# prompt_f64aea2d9937beb64360f17ab2c61615|we are in search of signs to believe.
# andamos em busca de signs
# andamos em busca de sinais para believe .
# andamos em busca de sinais para crer .
# estamos em busca de signs
#
# prompt_95cee4726df23156c8e43874b01ef5ce|i'm reading an interesting book.
# estou a ler um livro interessante .
# estou a ler um livro interessante . - a i ' m
# estou a ler um livro interessante . - estou a book .
# estou a ler um livro interessante . - estou bem .
# estou a ler um livro interessante . i ' m
# estou a ler um livro muito interessante
# estou a ler um livro muito interessante .
# estou lendo um livro interessante .
# estou ler um livro interessante .
# vou ler um livro interessante .
#
# prompt_a3b4e48d4558f45d641df9a173863a20|i have a colorful shirt.
# eu tenho uma camisa .
# eu tenho uma camisa de colorful
# eu tenho uma camisa de noite .
# tenho uma blusa de lã .
# tenho uma camisa .
# tenho uma camisa de colorful
# tenho uma camisa de noite .
#
# prompt_27e2b6c60e5322c95547ad6172eefceb|the actor's performance was excellent.
# o desempenho de actor era excelente .
# o desempenho do actor era excelente .
# o desempenho do actor foi excelente .
#
# prompt_adddf4f3ebac9da9e9b9b504ea3e395a|do you think i should buy this ring?
# acha que devo comprar este anel ?
# acha que eu devia comprar este anel ?
# acha que eu devia comprar este anel ? - não sei .
# acha que eu devia comprar este anel ? - não é preciso .
# achas que devia comprar este anel ?
# achas que devo comprar este anel ?
# achas que eu devia comprar este anel ?
# achas que eu devia comprar este anel ? - não sei .
# achas que eu devia comprar este anel ? - não é preciso .
# achas que eu devia comprar este anel ? you
#
# prompt_c5f7876b55b0bd791b92ca587d0ba6ff|luis has an egg.
# luis tem um egg .
# luis tem um ovo
# luis tem um ovo .
# luis tem um pensamento .
# luís tem um ovo .
#
# prompt_e49ae83c46c59566281f6a0699c82624|a small cup.
# bebamos uma descer .
# bebamos uma só copo .
# bebamos uma só copo . a
#
# prompt_6daa966631d60fcfd3fb255da3391309|he decided to choose a red cellphone.
# ele decidiu escolher um manto vermelho .
# ele decidiu escolher um red vermelho .
# ele decidiu escolher um vermelho red
# ele decidiu escolher uma cellphone . vermelha .
#
# prompt_ca33bb3bb4d91ebe64d8209257f271d1|we may go to work.
# podemos ir ao trabalho .
# podemos ir ao trabalho . - eu sei .
# podemos ir trabalhar !
# podemos ir trabalhar .
# podemos ir trabalhar . - bom dia .
# podemos ir trabalhar . - obrigado .
# vamos ao trabalho .
#
# prompt_3324bbf2b67f99bb952518afc530e431|science is the most difficult subject for me.
# a ciência para mim .
# a ciência é o mais difícil para mim .
#
# prompt_10574902aca89457b6f2e1766ee053ed|he continues walking.
# continua a andar
# continua a andar .
# continua a andar de passeio .
# continua a andar de pé .
# continua a andar de pé . he
# continua a andar de walking .
# continua continua a andar .
# ele continua a andar .
#
# prompt_5a5e9954be50995d9fb82b9de323aa89|his clothes are very old.
# a roupa dele é muito velha .
# as roupas dele são muito novas .
#
# prompt_f28cb673be0fc10dc608289e12799866|my computer screen is bigger than his.
# meu computador é maior que o dele .
# meu screen é maior que o dele .
# o meu computador tem mais que o dele .
# o meu computador é maior do que o dele .
# o meu computador é maior do que o dele . - computer
# o meu computador é maior do que o dele . - o quê ?
# o meu computador é maior do que o dele . is
# o meu computador é maior do que o meu .
# o meu computador é maior do que o seu .
# o meu computador é maior que o dele .
#
# prompt_9e5b48d1906ea87d72d966d2665c65e9|i will be paying with a credit card.
# eu pago - te um cartão de crédito .
# eu pago um cartão de crédito .
# eu vou pagar um cartão de crédito .
# eu vou pagar um cartão de crédito . - e eu também .
# eu vou pagar um cartão de crédito . - eu também .
# eu vou pagar um cartão de crédito . - não .
# eu vou pagar um cartão de crédito . _ bar _
# eu vou pagar um cartão de crédito . a
# vou me pagar um cartão de crédito .
# vou pagar um cartão de crédito .
#
# prompt_486f2135ffbf27382b264224f82e99c3|did you make a mistake?
# mistake ?
# não mistake ?
# você cometeu um erro .
# você mistake ?
#
# prompt_c2c7bf1cf972108c043ef497970f70da|the boys will be eating rice with chicken at my house.
# os rapazes vão comer arroz com frango em minha casa .
# os rapazes vão comer arroz com galinha em minha casa .
# os rapazes vão comer arroz de frango em casa .
# os rapazes vão comer arroz de frango em minha casa .
# os rapazes vão comer arroz de frango em minha casa . - não !
# os rapazes vão comer arroz de frango em minha casa . - não , obrigado .
# os rapazes vão comer arroz de frango em minha casa . - não .
# os rapazes vão comer arroz de frango em minha casa . - sim .
# os rapazes vão comer arroz de galinha .
#
# prompt_7fcf0020fdd6f60ef8fb4c142135532a|that is a lot to consider.
# isso é muito a considerar .
# isso é muito para considerar .
# isso é muito para considerar . - e então ?
# isso é muito para considerar . - tu também .
# isso é muito por considerar .
# é muito para considerar .
#
# prompt_69c393432d200e02dd1cfb33d51c2733|what disease does he have?
# que doença ele tem ?
# que doença tem ?
# que doença tem ele ?
# que doença é que ele tem ?
# que doença é que ele tem ? - he
# que doença é que ele tem ? what
# que doença é que ele tinha ?
# que doença é que ele têm ?
# que doença é que tem ?
# que mal tem ele ?
#
# prompt_966538f95744666d4a912e39e412aaf1|i need new shoes.
# eu preciso de sapatos novas .
# eu preciso de sapatos novos .
# eu preciso de sapatos novos . - não , pai .
# eu preciso de sapatos novos . - não , senhor .
# eu preciso de sapatos novos . - não .
# eu preciso de sapatos novos . _ bar _
# preciso de novos sapatos .
# preciso de sapatos .
# preciso de sapatos novas .
# preciso de sapatos novos .
#
# prompt_4d3f62bf7cb670405244b80c7ba88795|i will arrive saturday.
# eu irei chegar sábado .
# eu vou chegar sábado .
# irei chegar sábado .
# irei no sábado .
# vou chegar sábado .
#
# prompt_aaf34c2cae60cde5953ae0cada10facf|she finished work fifteen minutes ago.
# ela acabou de trabalhar há 15 minutos .
# ela acabou o trabalho há 15 minutos .
# ela acabou o trabalho há 15 minutos . - e o que é ?
# ela acabou o trabalho há 15 minutos . - não , por favor .
# ela acabou o trabalho há 15 minutos . - não .
# ela acabou o trabalho há 15 minutos . - não sei .
# ela acabou o trabalho há 15 minutos . - sim .
# ela acabou o trabalho há quinze minutos .
# ela terminou o trabalho há 15 minutos .
# terminou o trabalho há 15 minutos .
#
# prompt_8a2ed95370badfc309f366e7e8467104|i walk towards them.
# eu ando em direção a eles ,
# eu ando em direção a eles .
# eu ando em direção a eles . - eu them .
# eu ando em direção a eles . - i
# eu ando em direção a eles . - o que se passa ?
# eu ando em direção a eles . towards
# eu ando na direção a eles .
# eu ando na direção deles .
# walk em direção a eles .
#
# prompt_0520eb00cb266f6101e3770bb07bd3cd|wow, i can't believe that!
# não acredito nisso !
# não acredito nisto !
# não posso acreditar nisso !
# não posso acreditar nisto !
# uau , não posso acreditar nisso !
#
# prompt_db259981b89a67333b9db9908ec4380e|where did you buy the chemistry textbook?
# onde comprou a chemistry de chemistry
# onde você comprou a chemistry de chemistry
# onde você comprou a chemistry de química where
# onde é que comprou a chemistry de chemistry
# onde é que comprou a chemistry de química .
# onde é que comprou a chemistry de química where
# onde é que comprou a chemistry de química where where
#
# prompt_810c067587b8db78a08eeb8190454fd7|all right, thanks!
#  - está bem , obrigada !
#  - está bem , obrigado !
#  - está bem , obrigado ! - como foi ?
#  - está bem , obrigado ! - professor ?
#  - está bem , obrigado ! - sim .
# está bem , obrigado !
# muito bem , obrigado !
# tudo bem , obrigado !
#
# prompt_09f239182b26a3080f861bb8e132d801|our house is half a mile from here.
# a nossa casa fica a meia milha daqui .
# a nossa casa fica a meia milha daqui . - a nossa casa fica a meia milha .
# a nossa casa fica a meia milha daqui . - a nossa casa fica a meio daqui .
# a nossa casa fica a meia milha daqui . - não sei .
# a nossa casa fica a meia milha daqui . - oh , não !
# nossa casa fica a 800 metros daqui .
# nossa casa fica a meia km daqui .
# nossa casa fica a meia milha daqui .
# nossa casa fica a meio quilómetro daqui .
#
# prompt_bc00361222f78eb54b39397558cdc6da|where should we put the trash?
# onde devemos pôr as put
# onde devemos pôr as put - e o trash ?
# onde devemos pôr as put - e onde fica ?
# onde devemos pôr as put - e onde vamos ?
# onde devemos pôr as put - put
# onde devemos pôr o trash ?
# onde devemos pôr os put
#
# prompt_61cd8d9314c7cdec048afec4c9cc2b36|under the house.
# debaixo da casa ! debaixo da casa !
# debaixo da casa ! debaixo da casa .
# debaixo da casa ! debaixo da minha casa .
# debaixo da casa ! debaixo da minha casa . por debaixo da casa .
# debaixo da casa ! debaixo da minha casa . under
# debaixo da casa ! debaixo de casa .
# debaixo da casa , debaixo da casa .
#
# prompt_50c150bb5eb589e180a3600d1bf440b9|we speak chinese and english.
# falamos chinese e inglês .
# falamos em chinese e em inglês .
# falamos em chinese e inglês .
# falamos em chinese e inglês . - claro .
# falamos em chinese e inglês . - não , não .
# falamos em chinese e inglês . - não , senhor .
# falamos em chinese e inglês . - sim , senhor .
# falamos em inglês .
# falamos sobre english . e inglês .
#
# prompt_f7c973d0072fdbe66c91705a426cb819|does your eye hurt?
#  - estás ferido ?
# estás ferido ?
# o seu olho está ferido ?
#
# prompt_346a29267c2d758252ce13deeaa67c5c|i can't wait.
#  - não posso esperar .
#  - não posso esperar . - estou a ver .
#  - não posso esperar . - estou atrasado .
#  - não posso esperar . - eu sei .
# eu não posso esperar .
# mal posso esperar .
# não posso esperar .
# não posso esperar mais .
#
# prompt_c1de7a7af3c58c9756e34e9187791b91|the restaurant is past the bus station.
# o restaurante fica além da estação de autocarros .
# o restaurante fica além da estação de ônibus .
# o restaurante fica perto da estação de autocarros .
# o restaurante fica perto da estação de bus
# o restaurante fica perto da estação de ônibus .
#
# prompt_88e986ab303122942c7f426d6411e1b1|they support the cause.
# eles support a causa .
# eles support a causa disto .
# eles support a causa disto . _ bar _
# eles support a causa disto . they
# eles sustentar a causa .
#
# prompt_870662a5b59682af013ef0394f7d61f2|this cup is clean.
# esta chávena está limpa .
# esta taça está limpa .
#
# prompt_80982cf345cd9a88665936d2a8a4fe5f|when did their airplane take off?
# quando é que o avião deles off ?
# quando é que o avião deles off ? - ainda não .
# quando é que o avião deles off ? - ainda não airplane
# quando é que o avião deles off ? - airplane
# quando é que o avião deles off ? - quando é que o avião deles ?
# quando é que o avião deles off ? - quando é que o avião take
# quando é que o avião deles se airplane
# quando é que o avião se airplane
# quando é que o avião take
#
# prompt_753816935d3f33a7637fcc8d91b3f4cb|this hotel does not serve lunch.
# este hotel não serve de nada .
# este hotel não serve para almoçar .
# este hotel não serve para almoço .
# este hotel não serve para nada .
# este hotel não serve para o almoço .
# este hotel não serve para o almoço . - oh !
# este hotel não serve para o almoço . _ bar _
# este hotel não serve para o almoço . this
#
# prompt_e895eb0939808cd47e967a801159b242|thirteen, fourteen, fifteen.
#  - fifteen .
#  - fifteen . de hoje .
# fifteen .
# fifteen . .
#
# prompt_c2666f039b605cc6c61571d58e318237|we save money to open a restaurant.
# nós save dinheiro para abrir um restaurante .
# nós save dinheiro para abrir um restaurante . !
# nós save dinheiro para abrir um restaurante . - a
# nós save dinheiro para abrir um restaurante . - nós money
# nós save dinheiro para abrir um restaurante . _ bar _
# nós save dinheiro para abrir um restaurante . we
# pomos dinheiro para abrir um restaurante .
# poupar dinheiro para abrir um restaurante .
# save dinheiro para abrir um restaurante .
# save dinheiro para money um restaurante .
#
# prompt_216faef75a130e9e50c7770f23d292e5|i'm fine, thanks.
#  - estou bem , obrigada .
#  - estou bem , obrigada . - estou bem .
#  - estou bem , obrigada . - está bem .
#  - estou bem , obrigado .
#  - estou bem , obrigado . - obrigado .
# estou bem , obrigada .
# estou bem , obrigado .
# eu estou bem , obrigado .
#
# prompt_b4f47b7689839788d34877896de80330|young and beautiful.
# jovem e belo .
# jovem e bonita .
# jovem e bonito .
# jovem e lindo .
#
# prompt_23d0e34c639d712ead0ee6cfb57ab551|she heard the sound of the river.
# ela ouviram o som do rio .
# ela ouviu o barulho do rio .
# ela ouviu o som do rio
# ela ouviu o som do rio .
# ela ouviu o som do rio . - óptimo .
# ouviu o som do rio .
#
# prompt_2508c760bbdb80c28d863ddd2bb83687|we've already seen both of those places.
# já vimos ambas as coisas .
# já vimos ambas os lugares .
# já vimos ambos os lugares .
#
# prompt_c902d0e6e23470f88bb5a4b515e2cac1|the phrase is very long.
# a frase é muito long .
# a frase é muito longa .
# a frase é muito tarde .
# a frase é muito tempo .
#
# prompt_de204ef2cc38452f13dd3b9d89371259|he's angry because he has waited for you all morning.
# ele está irritado porque ele esperou toda a manhã .
# ele está irritado porque ele esperou toda a manhã contigo .
# ele está irritado porque ele esperou toda a manhã para si .
# ele está irritado porque ele esperou toda a manhã para ti .
# ele está irritado porque ele esperou toda a manhã para você .
# ele está irritado porque ele esperou toda a manhã para vocês .
# ele está irritado porque ele waited a manhã toda .
# ele está irritado porque ele waited toda a manhã .
# está zangado por ter esperado toda a manhã .
# está zangado porque esperava toda a manhã .
#
# prompt_e884415e2039a76b87b626cac5e139a1|where's the bus stop?
#  - onde está o autocarro ?
#  - onde está o autocarro ? !
#  - onde está o autocarro ? - não sei .
#  - onde está o autocarro ? - não tenho ônibus .
#  - onde está o autocarro ? _ bar _
#  - onde está o autocarro ? the
# onde está o autocarro ?
# onde fica o autocarro ?
#
# prompt_88837ae61b26f945c6f283d0641f5319|can i take a taxi to the hotel?
# posso ir de táxi até ao hotel ?
# posso levar um táxi até ao hotel ?
# posso levar um táxi para o hotel ?
# posso pegar um táxi até ao hotel ?
# posso pegar um táxi para o hotel ?
#
# prompt_057b7d083aa7e8ea7734fb7212a30378|it rained hard last night.
# choveu durante a noite .
# choveu duro ontem à noite .
# choveu muito ontem à noite .
# choveu ontem à noite .
# choveu uma noite passada .
#
# prompt_6719b294564e6185a2c90d797d4da1c7|he comes from a village in china.
# ele vem de uma aldeia em china .
# ele vem de uma aldeia na china .
# ele é de uma aldeia em china .
# ele é de uma aldeia na china .
# ele é de uma aldeia na china . - a sério ?
# é de uma aldeia na china .
#
# prompt_2e83e1a0e0246ea641d3c7c6739d2254|i'm going to study in france next year.
# vou estudar em year . no ano que vem .
# vou estudar na year . no ano que vem .
# vou estudar na year . no ano que vem . - estou a ver .
# vou estudar na year . no ano que vem . - está bem .
# vou estudar na year . no ano que vem . - não posso , mas não .
# vou estudar na year . no ano que vem . - não posso .
# vou estudar na year . no ano que vem ?
# vou estudar no ano que vem .
# vou estudar no year . ano que vem .
# vou estudar no year . no ano que vem .
#
# prompt_e0e0871b2e68c5b8458870f77d38ac6f|really bad.
# mesmo muito mau .
# mesmo muito mau . - é mesmo má .
# mesmo muito mau . - é muito mau .
# muito mau .
# é mesmo mau .
# é mesmo mau . - é muito mau .
#
# prompt_133fffbddcf8875e49aa580b5e877dc0|all of the doctors are nice.
# todos os doutores são simpáticos .
# todos os médicos são simpáticas .
# todos os médicos são simpáticos .
#
# prompt_757f8a961864200323a186d62096755a|where does he want to go?
# onde ele quer ir ?
# onde é que ele quer ir ?
# onde é que ele quer ir ? - to
# onde é que ele quer partir ?
# para onde ele quer ir ?
# para onde quer ele ir ?
# para onde quer ir ?
#
# prompt_58c92a14efd48fbcc66b16946b0a029d|do you know a good doctor?
#  - conhece um bom médico ?
#  - conhece um bom médico ? - eu também .
#  - conhece um bom médico ? - eu também sou .
#  - conhece um bom médico ? - não .
#  - conhece um bom médico ? - não sei .
#  - conhece um bom médico ? - sim .
# conhece um bom doutor ?
# conhece um bom médico ?
# conheces um bom médico ?
# você conhece um bom médico ?
#
# prompt_aee6f6171a985d857ccd674ccab17575|this hat is too big.
# esse chapéu é muito grande .
# este chapéu é demasiado grande .
# este chapéu é grande demais .
# este chapéu é muito grande .
#
# prompt_459c453553569c638da6cd51159b9c08|you deliver the food.
# deliver a comida .
# traga a comida .
# trouxe a comida .
# você entregar a comida .
#
# prompt_a06681478316b7c3ca16e63d4b71db93|hello, how are you?
# olá , como está ?
# olá , como estás ?
# olá , como estão ?
# olá , como vai ?
# olá , como vais ?
#
# prompt_d93ca6c2ad6a42d21f2f25700f577ed2|thanks, see you later!
#  - obrigado pela tarde !
#  - obrigado pela tarde ! - adeus .
#  - obrigado pela tarde ! - boa noite !
#  - obrigado pela tarde ! - boa noite .
#  - obrigado pela tarde ! - boa tarde .
# obrigado , até mais tarde !
# obrigado , até tarde !
# obrigado pela tarde !
#
# prompt_d59bf20fd7678405affbbb9d6e54e335|which sport is the most dangerous?
# qual é o tipo mais perigoso ?
# que diversão é o mais perigoso ?
# que tipo de diversão é o mais perigoso .
# que tipo de diversão é o mais perigoso ?
#
# prompt_7eac9f7aabec1caf39aa08590f050a53|that's not real gold, is it?
# isso não é ouro de verdade , não ?
# isso não é ouro de verdade , não é ?
# isso não é ouro de verdade , não é ? - sim .
# isso não é ouro de verdade , pois não ?
# isso não é ouro de verdade , pois não ? - eu sei .
# isso não é ouro de verdade , é ?
# isso não é ouro puro , pois não ?
# isso não é ouro verdadeiro ?
# não é ouro verdadeiro ?
#
# prompt_15a0ec57ab996695b649bdb864075d31|the dog has something in its mouth.
# o cão tem algo na boca .
# o cão tem alguma coisa na boca .
# o cão tem alguma coisa na boca . - sim .
# o cão tem qualquer coisa na boca .
#
# prompt_6c9e9d45ada593bb88253c9159dc6175|was there a light in the bathroom?
# havia uma luz do banheiro ?
# havia uma luz na casa de banho !
# havia uma luz na casa de banho .
# havia uma luz na casa de banho ?
# havia uma luz no banheiro ?
#
# prompt_49d64b349e7d5f1f7489d62cfed4ef69|are you in this line?
#  - está em linha ?
#  - está em linha ? !
#  - está em linha ? - eu .
#  - está em linha ? _ bar _
#  - está em linha ? are senhor .
# está em linha ?
# está na linha ?
# está nesta linha ?
# estás em linha ?
#
# prompt_0f2cda2ad3baeecb53febe1b68822b0f|you need to work hard.
# precisa trabalhar duro .
# precisa trabalhar muito .
# você precisa trabalhar com força .
# você precisa trabalhar com hard .
# você precisa trabalhar com você .
# você precisa trabalhar duro .
# você precisa trabalhar muito .
#
# prompt_59fc297bdc1693700b4fdc1f7945b741|what's your first name?
#  - qual é o seu primeiro nome ?
#  - qual é o seu primeiro nome ? - what ' s
# qual é o seu nome ?
# qual é o seu nome próprio ?
# qual é o seu primeiro nome ?
# qual é o seu primeiro nome ? - barani .
# qual é o seu primeiro nome ? - what ' s
# qual é o teu primeiro nome ?
#
# prompt_5931a3f955239c07c2eb0ca1d9a1d527|my husband has a degree in history.
# meu marido tem grau de história .
# meu marido tem history . na história .
# o meu marido tem grau de história .
# o meu marido tem grau de história . - claro .
# o meu marido tem grau de história . - por quê ?
# o meu marido tem grau de história . - sim , senhor .
# o meu marido tem grau de história . _ bar _
# o meu marido tem grau de história . in
#
# prompt_448aa471d6dfe46d4275c8ac356a3f34|bring the old battery to the store.
# traga a bateria antiga ao armazém .
# traga a bateria antiga à loja .
# traga a bateria velha para a loja .
# traga a velha bateria no armazém .
#
# prompt_223c9aed43645bc0f5551d154fe2cd41|everybody wants to drive a cleaner car.
# toda a gente quer conduzir um carro mais cleaner
# toda a gente quer conduzir um carro mais limpa .
# toda a gente quer conduzir um carro mais limpa . - bom .
# toda a gente quer conduzir um carro mais limpo .
# toda a gente quer conduzir um carro to
# toda a gente quer conduzir um carro à escola .
# todos querem conduzir um carro mais limpa .
#
# prompt_7ecf5abdd8f11ac2414651e2c90bb8c3|you guys can leave your bags on these shelves.
# podem deixar as malas na bags
# podem deixar as malas nestas bags
# podem deixar as malas no bags
# vocês deixam as malas nestas bags
# vocês podem deixar as malas nestas bags
# vocês podem deixar as malas nestas bags !
# vocês podem deixar as malas nestas bags - sim !
# vocês podem deixar as malas nestas bags - sim .
# vocês podem deixar as malas nestas bags these
#
# prompt_b7609417c7de288d7586338a5fd00cc8|we work together.
# fazemos isto juntos .
# fazemos tudo juntos .
# trabalhamos juntos .
#
# prompt_306c2748f0b4b6f7241f7eaa38be827e|what does he look like?
# como ele é ?
# como é ele ?
# como é que ele é ?
#
# prompt_739d120421171691368cfd5363ce79bf|make sure that this is the right address.
# certifique - se de que esta é a morada certa .
# certifique - se de que este é o endereço .
# certifique - se de que este é o endereço certo .
# certifique - se de que este é o endereço certo . - certo .
# certifique - se de que este é o endereço certo . - está bem .
# certifique - se de que este é o lugar certo .
# certifique - se de que este é o lugar certo . - obrigado .
# certifique - se que este é o endereço certo .
#
# prompt_411273a88f3169833d28797b367de210|there's a clock in my room.
# há um relógio em meu quarto .
# há um relógio na minha sala .
# há um relógio no meu quarto .
# há um relógio no meu quarto . - está bem , mãe .
# há um relógio no meu quarto . - está bem .
# há um relógio no meu quarto . - eu vou passar .
# há um relógio no meu quarto . - sim , senhor .
# há um relógio no meu quarto . - sim .
# tenho um relógio no meu quarto .
# tenho um relógio no quarto .
#
# prompt_6304362badc38c0393cbb4119ad04d6e|i will give you the money tomorrow.
# dar - lhe - ei o dinheiro amanhã .
# eu dar - lhe - ei o dinheiro amanhã .
# eu lhe darei o dinheiro amanhã .
# eu lhe darei o dinheiro amanhã . - o que foi ?
# eu lhe darei o dinheiro amanhã . - o que se passa ?
# eu lhe darei o dinheiro amanhã . - o que é ?
# eu lhe darei o dinheiro amanhã . the
# eu lhe darei o dinheiro amanhä .
# lhe darei o dinheiro amanhã .
# lhe darei o dinheiro amanhä .
#
# prompt_ea7e3b0c99a590894d077670fd12f216|if your aunt allows it.
# se a sua tia o permitir .
# se a sua tia permitir .
# se a tua tia o permite .
# se a tua tia permitir .
#
# prompt_bde3595ebafed50a7caae67fbbbbb421|he put the stamps in his cigarette case.
# ele coloca os selos na caixa de cigarros .
# ele coloca os selos na caixa de cigarros . . .
# ele coloca os selos na cigarreira .
# ele coloca os selos na cigarreira dele .
# ele stamps os selos na cigarreira dele .
# ele stamps os selos no caso do cigarro .
#
# prompt_cc9239db1854f849955482ca401f6442|he covered his face because of the wind.
# covered a cara pelo vento .
# covered a cara por causa do vento .
# ele covered a cara pelo vento .
# ele covered a cara por causa de vento .
# ele covered a cara por causa do vento
# ele covered a cara por causa do vento .
#
# prompt_05ccfb27bb07e78fafa39ef9c08ceb16|music is my daughter's favorite subject.
# a música é assunto da minha filha .
# a música é o assunto da minha filha , a música favorita
# a música é o assunto da minha filha , a música favorita . . .
# a música é o assunto da minha filha , a música preferida .
# a música é o assunto da minha filha .
# a música é o assunto de minha filha , a música preferida .
# música é o assunto da minha filha , a música preferida .
#
# prompt_5b67bd17f7d2d8d401f0c2a408b0db92|let's ask a salesperson.
# vamos fazer uma ask
# vamos pedir um ask
# vamos pedir uma ao ask
# vamos pedir uma ask
#
# prompt_bd9f2ea73e004251c54dd777a7ad1771|the balloons are filled with water.
# os balloons estão cheia de água .
# os balloons estão cheios de água
# os balloons estão cheios de água .
#
# prompt_5a037e00b443ed3eeec36137aa7ea1ad|there's nothing under the sofa.
#  - não há nada sob o sofá .
#  - não há nada sob o sofá . - aí está a sofa .
# não há nada debaixo do sofá .
# não há nada diante do sofá .
# não há nada no sofá .
# não há nada sob o sofá .
# não há nada sob o sofá . - aí está a sofa .
# não há nada sob o sofá . - não há nada a ser under
# não há nada sob o sofá . - é verdade ?
#
# prompt_95dbad407dece6b4f08e082daa250907|i don't remember the address.
# eu não me lembro do endereço .
# eu não me lembro do endereço . - não !
# não lembro do endereço .
# não me lembro da morada .
# não me lembro do endereço .
# não me lembro do endereço dela .
# não me lembro do endereço dela . - o quê ?
# não me lembro do endereço dele .
#
# prompt_a85399749aeee3e853d5702269f9fb36|were you sleeping during the meeting?
# estavas a dormir durante a reunião .
# estavas a dormir durante a reunião ?
# estiveste a dormir durante a reunião .
# estiveste a dormir durante a reunião ?
# estiveste a dormir durante o meeting ?
# sleeping durante a reunião ?
#
# prompt_9d66ea537f9427cbc0a0e0812da0866a|the computers in the laboratory work at high speed.
# o work do laboratório a fazer velocidade da speed .
# o work do laboratório começou a fazer velocidade da speed .
# o work do laboratório começou a fazer velocidade da speed . - a work
# o work do laboratório começou a fazer velocidade da speed . - speed .
# o work do laboratório começou a fazer velocidade da speed . no altura .
# o work do laboratório começou a fazer velocidade da speed . no laboratory
# o work do laboratório começou a fazer velocidade da velocidade .
# o work do laboratório começou a ganhar alta velocidade .
# o work do laboratório começou a work na alta velocidade .
#
# prompt_079788d532fd2a6adaf9b37d015968df|she doesn't remember me anymore.
# ela já não se lembra de mim .
# ela já não se lembra de mim agora .
# ela já não se lembra de mim de mim !
# ela já não se lembra de mim de mim , agora .
# ela já não se lembra de mim de mim .
# ela já não se lembra de mim de mim agora .
# ela já não se lembra de mim de mim de mim .
# ela não se lembra de mim .
# ela não se lembra mais de mim .
#
# prompt_a383e2704e9ff0b08d3fe3e695e86471|the blanket does not fit in that bag.
# o cobertor não serve naquela bolsa .
# o cobertor não serve naquela mala .
# o cobertor não serve nesse bag .
#
# prompt_df38f5e38de43ae22e501f8152d28204|my friend's house.
# a casa de meu amigo , é a casa do meu amigo .
# a casa de meu amigo , é a minha amiga .
# a casa de meu amigo , é da minha amiga .
# a casa de meu amigo , é dela .
# a casa de meu amigo , é minha amiga .
#
# prompt_b65735ca71b0d1fc97f0e4893e46eb62|where does she work?
#  - onde ela trabalha ?
# onde ela trabalha ?
# onde trabalha ?
# onde é que ela trabalha ?
# onde é que ela trabalha ? - não sei .
# onde é que ela trabalha ? she
# onde é que trabalha ?
#
# ...
# eu estou em busca do novo conhecimento .
# eu estou em busca do novo conhecimento . - eu também .
# eu estou em busca do novo conhecimento . _ bar _
# eu estou em busca do novo conhecimento . in
#
# prompt_c378bae3efdcdeaf23b3d1921220cfe5|the weather was nice in morocco.
# o tempo era bom , em morocco .
# o tempo estava bom , em morocco .
#
# prompt_c6c0c12da78a7e67ded7d19bdc989d19|i'm happy to stay longer.
# estou contente por ficar mais tempo .
# estou feliz de ficar mais tempo .
# estou feliz em ficar mais tempo .
# estou feliz por ficar mais tempo .
# fico feliz por ficar mais tempo .
#
# prompt_f9702a088a3f9f9a0e7abcbb6249b45b|eat pasta whenever you want.
# coma algumas pasta quando quiser .
# coma algumas pasta quando quiser . - bom jantar .
# coma algumas pasta quando quiser . - bom trabalho , senhor .
# coma das pasta quando quiser .
# coma das pasta quando quiser . - bom trabalho , senhor .
# coma das pasta quando quiser . - certo .
# coma das pasta quando quiser . - pasta
# coma das peças quando quiser .
# coma já , quando quiser .
# coma pasta quando quiser .
#
# prompt_683b8af907d93d4c28670d319ba64340|i don't know the way to the stadium.
# eu não sei o caminho para o the
# eu não sei o caminho para o the !
# eu não sei o caminho para o the - não , senhor .
# eu não sei o caminho para o the - não sei o caminho .
# eu não sei o caminho para o the don ' t
# eu não sei o caminho para o the não sei o caminho para o the
# não sei o caminho para a to
# não sei o caminho para o forte .
# não sei o caminho para o the
# não sei o caminho para os the
#
# prompt_cf4d8d0a406507a25589a429ec7beb71|the professor usually writes on the blackboard.
# o professor costuma escrever na loja de costura .
# o professor costuma escrever na loja de máquinas .
# o professor costuma escrever na loja de máquinas . não sabia .
# o professor costuma escrever na loja de máquinas . não é fácil .
# o professor costuma escrever na loja de máquinas . não é preciso .
# o professor costuma escrever na loja de professor
# o professor costuma escrever na the
# o professor costuma escrever no professor
#
# prompt_42b76104a15c1cda8c8b2d59bb5d5bdc|we cannot hear the music.
# não conseguimos ouvir a música .
# não podemos ouvir a música .
# nós não podemos ouvir a música .
# nós não podemos ouvir a música . - está bem .
# nós não podemos ouvir a música . - música ?
# nós não podemos ouvir a música . cannot
#
# prompt_122c0ca8711bd2435fd16e55000fd8c5|do you know how important your grades are?
# sabes como são as tuas notas ?
# sabes o que são as suas notas ?
# sabes o que são as tuas notas ?
# sabes quais são as suas notas ?
# você sabe o que são as suas notas ?
#
# prompt_1ce560d26896f95b57e9bfdc1623513b|this is what will change us.
# isto é o que nos change
# isto é o que nos irá mudar .
# isto é o que nos mudará a nós .
# isto é o que nos vai mudar .
#
# prompt_12503c418e6dfd80b5f43dafde72543a|was there someone outside her room?
# estava alguém do outro lado do quarto ?
# estava alguém do outro lado do quarto ? - não .
# estava alguém do outro lado do quarto ? - sim .
# estava alguém do outro lado do quarto ? _ bar _
# estava alguém do outro lado do quarto ? someone
# estava alguém do outro lado do seu quarto ?
# estava alguém do quarto dela ?
# estava alguém lá fora do quarto ?
# estava alguém lá fora no quarto ?
#
# prompt_f6dc6e811f619b985a0b2bd3ab0d94eb|we have two girls.
# nós temos duas meninas .
# nós temos duas meninas . - a próxima !
# nós temos duas meninas . - a sério ?
# nós temos duas meninas . - não há ninguém .
# nós temos duas meninas . _ bar _
# nós temos duas meninas . girls .
# temos duas garotas .
# temos duas meninas .
# temos duas raparigas .
#
# prompt_0dca02415fa688cdc351e9405e61b8ce|it'll be difficult.
#  - vai ser difícil .
#  - vai ser difícil . - eu sei .
#  - vai ser difícil . - não sei .
#  - vai ser difícil . - não vai ser .
# será difícil .
# vai ser difícil .
# vai ser muito difícil .
#
# prompt_5a5201a7277ad1b09a81ea1b4c2265aa|mom said you should eat fewer cookies.
# a minha mãe disse que você devia comer menos bolachas .
# a minha mãe disse que você devia comer menos bolinhos .
# a minha mãe disse que você devia comer menos cookies .
# a minha mãe disse que você devia comer menos cookies . - cookies .
# a minha mãe disse que você devia comer menos cookies . mom
# a tua mãe disse que devias comer menos bolachas .
# a tua mãe disse que devias comer menos cookies .
# mamãe disse que você deveria comer menos cookies .
# mamãe disse que você devia comer menos cookies .
#
# prompt_711ce63a7a4a625a1acfde802acc215c|he drank a glass of wine, and then he went to sleep.
# bebeu um copo de vinho e depois adormecer .
# bebeu um copo de vinho e depois adormeceu .
# bebeu um copo de vinho e depois ele adormecer .
# bebeu um copo de vinho e depois foi dormir .
# bebeu um copo de vinho e depois foi dormir . - está bem .
# bebeu um copo de vinho e depois foi dormir . - está bom .
# bebeu um copo de vinho e depois foi dormir . - sim , senhor .
# bebeu um copo de vinho e depois foi dormir . - sim .
# bebeu um copo de vinho e depois foi dormir . to
# tomou um copo de vinho e depois ele adormecer .
#
# prompt_02bdd0de3970e7c90aece3a2799fe916|my roommate is studying african religions.
# a minha colega estuda religions .
# minha colega colega estuda religions .
# minha colega de quarto está aprender religions .
# minha colega de quarto está estudando as religions .
# minha colega de quarto está estudando para my religions .
# minha colega estuda religions .
# minha colega estuda religions . religions .
#
# prompt_60dfd8713b51aa5ee9784f533f475cc8|my father has been to australia twice.
# meu pai esteve a twice . duas vezes .
# meu pai esteve em to duas vezes .
# meu pai esteve em to duas vezes ?
# meu pai esteve no to duas vezes .
# meu pai foi a twice . duas vezes .
#
# prompt_cca8f1187d5e1d501243ab000b013184|our families live near here.
#  - as nossas famílias vivem perto daqui .
#  - as nossas famílias vivem perto daqui . - não posso .
#  - as nossas famílias vivem perto daqui . - também eu .
#  - as nossas famílias vivem perto de aqui .
#  - as nossas famílias vivem perto de cá .
#  - as nossas famílias vivem perto disto .
# as nossas famílias vivem aqui perto .
# as nossas famílias vivem perto daqui .
# nossas famílias vivem perto daqui .
#
# prompt_7d609c686ffdb8c17bd05528c7c7ffbf|we were driving until midnight last night.
# driving até à meia - noite , ontem .
# driving até à meia - noite , ontem à noite .
# driving até à meia - noite , ontem à noite . - driving
# driving até à meia - noite , ontem à noite . - e então ?
# driving até à meia - noite , ontem à noite . - e tu ?
# driving até à meia - noite , ontem à noite . - não posso .
# driving até à meia - noite , ontem à noite ?
# driving até à meia - noite e noite .
# íamos até à meia - noite , ontem .
# íamos até à meia - noite , ontem à noite .
#
# prompt_e9af8ecf87866d982c90dd9b95fed422|my department has a staff of 30 people.
# meu departamento tem uma department de 30 pessoas .
# meu departamento tem uma equipe de 30 homens .
# meu departamento tem uma equipe de 30 pessoas .
# o meu departamento tem uma department de 30 pessoas .
# o meu departamento tem uma department de 30 pessoas . - um grupo .
# o meu departamento tem uma equipe de 30 pessoas .
# o meu departamento tem uma equipe de 30 pessoas . - não obrigado .
# o meu departamento tem uma equipe de 30 pessoas . - não é ?
# o meu departamento tem uma equipe de 30 pessoas . a
#
# prompt_74da3329285e41478d2f14868e519eb0|my brother is happy.
# meu irmão está contente .
# meu irmão está feliz .
# o meu irmão está feliz .
# o meu irmão está feliz . is
#
# prompt_67467fda872756f3048b34f5e19cbafc|he slept for only four hours last night.
# ele dormiu apenas quatro horas esta noite .
# ele dormiu apenas quatro horas à noite .
# ele dormiu só quatro horas a noite passada .
# ele dormiu só quatro horas esta noite .
# ele só dormiu quatro horas a noite passada .
# ele só dormiu quatro horas a noite passada . - claro .
# ele só dormiu quatro horas a noite passada . - pois é .
# ele só dormiu quatro horas a noite passada . he
# ele só dormiu quatro horas a noite passada . não entende ?
# ele só dormiu quatro horas a noite passada . não é verdade !
#
# prompt_c663eef20fc6c600ab9b572a53a9c646|i do not get up early on fridays.
# eu não me early cedo .
# eu não me early cedo em early
# eu não me early cedo em sair da on
# eu não me early cedo em sair de on
# eu não me early cedo em sair do hotel .
# eu não me early cedo em sair do jogo .
# eu não me early cedo em sair do on
# eu não me early cedo no early
# eu não me early em early
# eu não up cedo em early
#
# prompt_f1d562c0491711601802541aba8eee5e|i will give you an answer in a day or two.
# answer uma resposta dentro de um ou dois .
# eu dar - lhe - ei uma resposta dentro de um dia ou dois .
# eu dar - lhe - ei uma resposta dentro de um dia ou duas .
# eu dar - lhe - ei uma resposta num dia ou dois .
# eu lhe darei uma resposta dentro de um dia ou dois .
# eu lhe darei uma resposta dentro de um dia ou dois . - o quê ?
# eu lhe darei uma resposta dentro de um dia ou dois dias .
# eu lhe darei uma resposta dentro de um dia ou dois minutos .
# eu lhe darei uma resposta dentro de um dia ou duas .
# eu lhe darei uma resposta num dia ou dois .
#
# prompt_02849106661086f9d767081d934686d8|she's an excellent singer.
#  - é uma excelente cantora .
# ela é excelente cantora .
# ela é uma excelente cantora .
# ela é uma excelente cantora . - eu sei .
# ela é uma excelente cantora . - não .
# ela é uma excelente cantora . - não sei .
# ela é uma excelente cantora . - não é isso .
# ela é uma excelente cantora . she ' s
# é uma excelente cantora .
#
# prompt_f6170caaee929c7af492f222f145bae8|what a beautiful garden you have!
# que belo jardim tem !
# que jardim belo tem !
# que jardim tão belo que have !
# que jardim tão belo que tem !
# que jardim tão belo que tu !
# que jardim tão belo que você tem !
# que jardim tão bonito !
# que lindo jardim tem !
#
# prompt_e4435dd76b636249bcf44baa88e11dd1|which blouse do you like?
# qual blusa gosta ?
# qual blusa gostas ?
# qual blusa você gosta ?
#
# prompt_fce04dfafee3388ea89431af282907e3|our team never wins.
# a nossa equipa nunca ganha .
# a nossa equipa não ganha .
# a nossa equipe nunca ganha .
#
# prompt_8a64df0e6e525dd2d35fdfbe97f37dae|i could not find my glasses.
# eu não conseguia encontrar os meus copos .
# eu não conseguia encontrar os meus óculos .
# eu não conseguia encontrar os meus óculos . - eu não encontrei .
# eu não conseguia encontrar os meus óculos . - eu também não .
# eu não conseguia encontrar os meus óculos . - não .
# eu não podia encontrar os meus copos .
# eu não podia encontrar os meus óculos .
# não consegui encontrar os meus óculos .
#
# prompt_a21091ab97baf92a843443160c1df849|what kind of fish do you have?
# que espécie de peixe tem ?
# que peixe você tem ?
# que tipo de peixe tem ?
# que tipo de peixe tem ? - fish
# que tipo de peixe tem ? - não sei .
# que tipo de peixe tem ? - seis .
# que tipo de peixe tens ?
# que tipo de peixe é ?
#
# prompt_dac5d5ab335bbe2e057a3aa07d0069a7|there are enough pears for everyone.
#  - como estão as pears
#  - como estão as pears - como está ?
#  - como estão as pears - como estão ?
#  - como estão as pears - sim .
#  - como estão as pears - talvez .
#
# prompt_9c79a526b3d47c34e4fa09e643848f2b|i've never learned to play a musical instrument.
# nunca aprendi a tocar algo musical .
# nunca aprendi a tocar instrumento musical
# nunca aprendi a tocar instrumento musical .
# nunca aprendi a tocar instrumento musical ?
# nunca aprendi a tocar objecto musical .
#
# prompt_e7d3dfe57d34259711745a1351f15a99|i need to cook the beef.
# eu preciso cozinhar o carne .
# eu preciso cozinhar o carne . !
# eu preciso cozinhar o carne . - não , capitão the
# eu preciso cozinhar o carne . _ bar _
# eu preciso cozinhar o carne . the em casa .
# preciso cozinhar .
# preciso cozinhar a carne .
# preciso cozinhar o bife .
# preciso cozinhar o carne .
# preciso preparar a carne .
#
# prompt_e0a0faad1928487c2e1aa97380201c1b|who do you visit?
#  - quem é que casou ?
#  - quem é que casou ? - um momento .
# quem é que casou ?
# quem é que visit ?
# quem é que você chega ?
#
# prompt_57db126ed7045f38ece3d7456d7330bf|it took me an hour and a half to get home.
# demorei uma hora e meia para chegar a casa .
# demorei uma hora e meio para chegar a casa .
# levei uma hora e meia para chegar a casa .
# levei uma hora e meio para chegar a casa .
# tomei uma hora e meia para chegar a casa .
#
# prompt_9e95266f353feb31f145713c9c906415|those shoes are made in italy.
# aqueles sapatos são feitos em in
# aqueles sapatos são feitos em shoes
# esses sapatos são feitos em in
# esses sapatos são feitos em shoes
# estes sapatos são feitos em shoes
#
# prompt_d4fe80883d6366222e32233ae563a1a8|what is he wearing today?
# o que ele está a usar hoje ?
# o que ele está a usar hoje ? - what
# o que ele está usando hoje ?
# o que está ele a usar agora ?
# o que está ele a usar hoje ?
# o que está ele a usar hoje ? - não , senhor .
# o que está ele a usar hoje ? - não sei .
# o que está ele a usar hoje ? - what
# o que tem ele hoje ?
# que está ele a usar hoje ?
#
# prompt_67549f87c24f8b6391572c2844610c6b|i will introduce you to my girlfriend.
# eu vou apresentá - lo à minha namorada .
# vou apresentá - lo à minha amiga !
# vou apresentá - lo à minha amiga ! - o quê ?
# vou apresentá - lo à minha amiga ! eu vou apresentá - lo à minha namorada .
# vou apresentá - lo à minha amiga ! eu vou girlfriend .
# vou apresentá - lo à minha amiga ! will
# vou apresentá - lo à minha amiga .
# vou apresentá - lo à minha namorada .
# vou girlfriend . à minha namorada .
#
# prompt_5a0119eaaf190e44e7e90f35c1f1d6d2|these are the books that i finished.
# estas são os livros que finished .
# estes são os livros que eu finished .
# estes são os livros que eu finished . - não .
# estes são os livros que eu finished . a fazer .
# estes são os livros que eu finished . a mim .
# estes são os livros que eu finished . a si .
# estes são os livros que eu fiz .
# estes são os livros que eu fiz ?
# estes são os livros que finished .
# são os livros que finished .
#
# prompt_656dc1fad9354513e2c13e92d2ba6d9c|what does your mom look like?
#  - como é a tua mãe ?
# como é a sua mãe ?
# como é a tua mãe ?
# como é que a tua mãe me parece ?
# como é que a tua mãe se parece ?
# como é que a tua mãe é ?
# como é que tua mãe se parece ?
#
# prompt_2ce5e0ce6d4a4d5f4735492529f94f30|they took care of the baby.
# eles se care do bebé .
# eles tomaram conta do bebé .
#
# prompt_c5fd120dbffe4e3188bdb5405cc80a22|click in the box.
# click na caixa .
#
# prompt_b6718e0c9de984f88290445b46ee5e22|the situation is worse than we thought.
# a situação é pior do que nós thought .
# a situação é pior do que nós thought . - a situação é que nós worse
# a situação é pior do que nós thought . - a situação é que worse
# a situação é pior do que nós thought . - a worse
# a situação é pior do que nós thought . - não sei .
# a situação é pior do que nós thought . than
# a situação é pior do que pensávamos .
# a situação é pior do que thought .
#
# prompt_63cce1f1a7551cdf988d913618c8aeb4|this price is for children five and over.
# este preço é para as crianças cinco e mais .
# este preço é para as crianças cinco e mais acima .
# este preço é para as crianças cinco e mais para cá .
# este preço é para as crianças cinco e mais para fora .
# este preço é para as crianças cinco e mais por um .
# este preço é para as crianças cinco e mais por um . - e o que se passa ?
# este preço é para as crianças cinco e mais por um . - e o que é isso ?
# este preço é para as crianças cinco e mais por um . - pois não .
# este preço é para as crianças cinco e mais por um . - pois é .
#
# prompt_aaa8ab8b23b101f00d14b280f97bffc5|the girl always wants to win.
# a garota quer sempre ganhar .
# a menina quer sempre ganhar .
# a miúda quer sempre ganhar .
# a rapariga quer sempre ganhar .
#
# prompt_d5ed01dc40e1ef1a3c9405fac10afb3c|we generally eat fish on friday.
# geralmente comemos peixe na sexta .
# geralmente comemos peixes na sexta .
# normalmente comemos peixe na sexta .
# normalmente comemos peixes na sexta .
#
# prompt_009dba641d3707b90f0dcb6a7394b9bf|the burgers are fantastic!
# as fantastic ! são fantastic !
# os fantastic ! são fantastic !
# os fantastic ! são fantástico !
